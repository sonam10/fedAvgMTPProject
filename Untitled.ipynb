# %%
import random
import copy

import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

from util import view_10
from util import num_params
from data import fetch_dataset, data_to_tensor, iid_partition_loader, noniid_partition_loader

# %%
# set random seeds
np.random.seed(0)
torch.manual_seed(0)
random.seed(0)

# set device
device = 'cuda' if torch.cuda.is_available() else 'cpu'
print("| using device:", device)
# Out:
# | using device: cpu

# %%
# hyperparams
bsz = 10

# %%
train_data, test_data = fetch_dataset()

test_loader = torch.utils.data.DataLoader(test_data, batch_size = 1000, shuffle=False) # inference bsz=1000
debug_loader = torch.utils.data.DataLoader(train_data, bsz)
img, label = next(iter(debug_loader))
view_10(img, label)

# %%
# get client dataloaders
iid_client_train_loader = iid_partition_loader(train_data, bsz = bsz)
noniid_client_train_loader = noniid_partition_loader(train_data, bsz = bsz)

# %%
# iid
label_dist = torch.zeros(10)
for (x,y) in iid_client_train_loader[25]:
    label_dist+= torch.sum(F.one_hot(y, num_classes=10), dim=0)
print("iid: ", label_dist)
view_10(x,y)
# Out:
# iid:  tensor([59., 67., 65., 61., 55., 52., 55., 64., 48., 74.])

# %%
# non-iid
label_dist = torch.zeros(10)
for (x,y) in noniid_client_train_loader[25]:
    label_dist+= torch.sum(F.one_hot(y,num_classes=10), dim=0)
print("non-iid: ", label_dist)
view_10(x,y)
# Out:
# non-iid:  tensor([300.,   0.,   0., 300.,   0.,   0.,   0.,   0.,   0.,   0.])

# %% [markdown]
# MODELS

# %%
criterion = nn.CrossEntropyLoss()

def validate(model):
    model = model.to(cuda)
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for (t, (x,y)) in enumerate(test_loader):
            x = x.to(cuda)
            y = y.to(cuda)
            out = model(x)
            correct += torch.sum(torch.argmax(out, dim=1) == y).item()
            total += x.shape[0]
    return correct/total

# %%
# define fully connected NN
class MLP(nn.Module):
    def __init__(self):
        super(MLP, self).__init__()
        self.fc1 = nn.Linear(784, 200);
        self.fc2 = nn.Linear(200, 200);
        self.out = nn.Linear(200, 10);

    def forward(self, x):
        x = x.flatten(1) # [B x 784]
        x = F.relu(self.fc1(x)) # [B x 200]
        x = F.relu(self.fc2(x)) # [B x 200]
        x = self.out(x) # [B x 10]
        return x

print(MLP())
print(num_params(MLP()))
# Out:
# MLP(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (out): Linear(in_features=200, out_features=10, bias=True)
# )
# 199210

# %%
criterion = nn.CrossEntropyLoss()

def validate(model):
    model = model.to(cuda)
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for (t, (x,y)) in enumerate(test_loader):
            x = x.to(cuda)
            y = y.to(cuda)
            out = model(x)
            correct += torch.sum(torch.argmax(out, dim=1) == y).item()
            total += x.shape[0]
    return correct/total

# %%
# define cnn
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(1, 32, 5) 
        self.conv2 = nn.Conv2d(32, 64, 5)
        self.fc = nn.Linear(1024, 512)
        self.out = nn.Linear(512, 10)

    def forward(self, x):
        x = F.max_pool2d(self.conv1(x), 2, 2) # [B x 32 x 12 x 12]
        x = F.max_pool2d(self.conv2(x), 2, 2) # [B x 64 x 4 x 4]
        x = x.flatten(1) # [B x 1024]
        x = F.relu(self.fc(x)) # [B x 512]
        x = self.out(x) # [B x 10]
        return x

print(CNN())
print(num_params(CNN()))
# Out:
# CNN(
#   (conv1): Conv2d(1, 32, kernel_size=(5, 5), stride=(1, 1))
#   (conv2): Conv2d(32, 64, kernel_size=(5, 5), stride=(1, 1))
#   (fc): Linear(in_features=1024, out_features=512, bias=True)
#   (out): Linear(in_features=512, out_features=10, bias=True)
# )
# 582026

# %% [markdown]
# Traning

# %%
criterion = nn.CrossEntropyLoss()

def validate(model):
    model = model.to(cuda)
    model.eval()
    correct = 0
    total = 0
    with torch.no_grad():
        for (t, (x,y)) in enumerate(test_loader):
            x = x.to(cuda)
            y = y.to(cuda)
            out = model(x)
            correct += torch.sum(torch.argmax(out, dim=1) == y).item()
            total += x.shape[0]
    return correct/total

# %%
def train_client(id, client_loader, global_model, num_local_epochs, lr):
    local_model = copy.deepcopy(global_model)
    local_model = local_model.to(cuda)
    local_model.train()
    optimizer = torch.optim.SGD(local_model.parameters(), lr=lr)

    for epoch in range(num_local_epochs):
        for (i, (x,y)) in enumerate(client_loader):
            x = x.to(cuda)
            y = y.to(cuda)
            optimizer.zero_grad()
            out = local_model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()

    return local_model

def running_model_avg(current, next, scale):
    if current == None:
        current = next
        for key in current:
            current[key] = current[key] * scale
    else:
        for key in current:
            current[key] = current[key] + (next[key] * scale)
    return current

# %%
def fed_avg_experiment(global_model, num_clients_per_round, num_local_epochs, lr, client_train_loader, max_rounds, filename):
    round_accuracy = []
    for t in range(max_rounds):
        print("starting round {}".format(t))

        # choose clients
        clients = np.random.choice(np.arange(100), num_clients_per_round, replace = False)
        print("clients: ", clients)

        global_model.eval()
        global_model = global_model.to(cpu)
        running_avg = None

        for i,c in enumerate(clients):
            # train local client
            print("round {}, starting client {}/{}, id: {}".format(t, i+1,num_clients_per_round, c))
            local_model = train_client(c, client_train_loader[c], global_model, num_local_epochs, lr)

            # add local model parameters to running average
            running_avg = running_model_avg(running_avg, local_model.state_dict(), 1/num_clients_per_round)
        
        # set global model parameters for the next step
        global_model.load_state_dict(running_avg)

        # validate
        val_acc = validate(global_model)
        print("round {}, validation acc: {}".format(t, val_acc))
        round_accuracy.append(val_acc)

        if (t % 10 == 0):
          np.save(filename+'_{}'.format(t)+'.npy', np.array(round_accuracy))

    return np.array(round_accuracy)

# %% [markdown]
# MLP Experiments

# %%
mlp = MLP()
print(mlp)
print("total params: ", num_params(mlp))
# Out:
# MLP(
#   (fc1): Linear(in_features=784, out_features=200, bias=True)
#   (fc2): Linear(in_features=200, out_features=200, bias=True)
#   (out): Linear(in_features=200, out_features=10, bias=True)
# )
# total params:  199210

# %%
cpu = torch.device('cpu')
cuda = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# MLP - iid - m=10 experiment
mlp_iid_m10 = copy.deepcopy(mlp)
acc_mlp_iid_m10 = fed_avg_experiment(mlp_iid_m10, num_clients_per_round=10, 
                                 num_local_epochs=1,
                                 lr=0.05,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=100,
                                 filename='./acc_mlp_iid_m10')
print(acc_mlp_iid_m10)
np.save('./acc_mlp_iid_m10.npy', acc_mlp_iid_m10)
# Out:
# starting round 0
# clients:  [42 96 58 14 72  4 47 64 57 63]
# round 0, starting client 1/10, id: 42
# round 0, starting client 2/10, id: 96
# round 0, starting client 3/10, id: 58
# round 0, starting client 4/10, id: 14
# round 0, starting client 5/10, id: 72
# round 0, starting client 6/10, id: 4
# round 0, starting client 7/10, id: 47
# round 0, starting client 8/10, id: 64
# round 0, starting client 9/10, id: 57
# round 0, starting client 10/10, id: 63
# round 0, validation acc: 0.8103
# starting round 1
# clients:  [54 84 33 53  2 49 48 82 41 66]
# round 1, starting client 1/10, id: 54
# round 1, starting client 2/10, id: 84
# round 1, starting client 3/10, id: 33
# round 1, starting client 4/10, id: 53
# round 1, starting client 5/10, id: 2
# round 1, starting client 6/10, id: 49
# round 1, starting client 7/10, id: 48
# round 1, starting client 8/10, id: 82
# round 1, starting client 9/10, id: 41
# round 1, starting client 10/10, id: 66
# round 1, validation acc: 0.8811
# starting round 2
# clients:  [89 56 37 46  2 90 13 15 58 67]
# round 2, starting client 1/10, id: 89
# round 2, starting client 2/10, id: 56
# round 2, starting client 3/10, id: 37
# round 2, starting client 4/10, id: 46
# round 2, starting client 5/10, id: 2
# round 2, starting client 6/10, id: 90
# round 2, starting client 7/10, id: 13
# round 2, starting client 8/10, id: 15
# round 2, starting client 9/10, id: 58
# round 2, starting client 10/10, id: 67
# round 2, validation acc: 0.8982
# starting round 3
# clients:  [93 49 68 23  9 67 72 82 92 85]
# round 3, starting client 1/10, id: 93
# round 3, starting client 2/10, id: 49
# round 3, starting client 3/10, id: 68
# round 3, starting client 4/10, id: 23
# round 3, starting client 5/10, id: 9
# round 3, starting client 6/10, id: 67
# round 3, starting client 7/10, id: 72
# round 3, starting client 8/10, id: 82
# round 3, starting client 9/10, id: 92
# round 3, starting client 10/10, id: 85
# round 3, validation acc: 0.9065
# starting round 4
# clients:  [93 22  6 28 80 94 39 11 73  2]
# round 4, starting client 1/10, id: 93
# round 4, starting client 2/10, id: 22
# round 4, starting client 3/10, id: 6
# round 4, starting client 4/10, id: 28
# round 4, starting client 5/10, id: 80
# round 4, starting client 6/10, id: 94
# round 4, starting client 7/10, id: 39
# round 4, starting client 8/10, id: 11
# round 4, starting client 9/10, id: 73
# round 4, starting client 10/10, id: 2
# round 4, validation acc: 0.915
# starting round 5
# clients:  [98  3  7 79 64 40 22 27 52 47]
# round 5, starting client 1/10, id: 98
# round 5, starting client 2/10, id: 3
# round 5, starting client 3/10, id: 7
# round 5, starting client 4/10, id: 79
# round 5, starting client 5/10, id: 64
# round 5, starting client 6/10, id: 40
# round 5, starting client 7/10, id: 22
# round 5, starting client 8/10, id: 27
# round 5, starting client 9/10, id: 52
# round 5, starting client 10/10, id: 47
# round 5, validation acc: 0.9198
# starting round 6
# clients:  [ 2 15 72 21 89 91 41 45 51 88]
# round 6, starting client 1/10, id: 2
# round 6, starting client 2/10, id: 15
# round 6, starting client 3/10, id: 72
# round 6, starting client 4/10, id: 21
# round 6, starting client 5/10, id: 89
# round 6, starting client 6/10, id: 91
# round 6, starting client 7/10, id: 41
# round 6, starting client 8/10, id: 45
# round 6, starting client 9/10, id: 51
# round 6, starting client 10/10, id: 88
# round 6, validation acc: 0.9253
# starting round 7
# clients:  [96 77 98 53 32 18 64 82 31 61]
# round 7, starting client 1/10, id: 96
# round 7, starting client 2/10, id: 77
# round 7, starting client 3/10, id: 98
# round 7, starting client 4/10, id: 53
# round 7, starting client 5/10, id: 32
# round 7, starting client 6/10, id: 18
# round 7, starting client 7/10, id: 64
# round 7, starting client 8/10, id: 82
# round 7, starting client 9/10, id: 31
# round 7, starting client 10/10, id: 61
# round 7, validation acc: 0.9292
# starting round 8
# clients:  [81 50 91 56 75 17 40 85 71 35]
# round 8, starting client 1/10, id: 81
# round 8, starting client 2/10, id: 50
# round 8, starting client 3/10, id: 91
# round 8, starting client 4/10, id: 56
# round 8, starting client 5/10, id: 75
# round 8, starting client 6/10, id: 17
# round 8, starting client 7/10, id: 40
# round 8, starting client 8/10, id: 85
# round 8, starting client 9/10, id: 71
# round 8, starting client 10/10, id: 35
# round 8, validation acc: 0.9308
# starting round 9
# clients:  [69 62 84 98 19  1 12 25 59 58]
# round 9, starting client 1/10, id: 69
# round 9, starting client 2/10, id: 62
# round 9, starting client 3/10, id: 84
# round 9, starting client 4/10, id: 98
# round 9, starting client 5/10, id: 19
# round 9, starting client 6/10, id: 1
# round 9, starting client 7/10, id: 12
# round 9, starting client 8/10, id: 25
# round 9, starting client 9/10, id: 59
# round 9, starting client 10/10, id: 58
# round 9, validation acc: 0.9345
# starting round 10
# clients:  [18 15 62 73  8 25 11 52 43  6]
# round 10, starting client 1/10, id: 18
# round 10, starting client 2/10, id: 15
# round 10, starting client 3/10, id: 62
# round 10, starting client 4/10, id: 73
# round 10, starting client 5/10, id: 8
# round 10, starting client 6/10, id: 25
# round 10, starting client 7/10, id: 11
# round 10, starting client 8/10, id: 52
# round 10, starting client 9/10, id: 43
# round 10, starting client 10/10, id: 6
# round 10, validation acc: 0.939
# starting round 11
# clients:  [79 63 77 59 31 61 14  6 48 41]
# round 11, starting client 1/10, id: 79
# round 11, starting client 2/10, id: 63
# round 11, starting client 3/10, id: 77
# round 11, starting client 4/10, id: 59
# round 11, starting client 5/10, id: 31
# round 11, starting client 6/10, id: 61
# round 11, starting client 7/10, id: 14
# round 11, starting client 8/10, id: 6
# round 11, starting client 9/10, id: 48
# round 11, starting client 10/10, id: 41
# round 11, validation acc: 0.9381
# starting round 12
# clients:  [46 72 98 40 43 64 18 13 39 11]
# round 12, starting client 1/10, id: 46
# round 12, starting client 2/10, id: 72
# round 12, starting client 3/10, id: 98
# round 12, starting client 4/10, id: 40
# round 12, starting client 5/10, id: 43
# round 12, starting client 6/10, id: 64
# round 12, starting client 7/10, id: 18
# round 12, starting client 8/10, id: 13
# round 12, starting client 9/10, id: 39
# round 12, starting client 10/10, id: 11
# round 12, validation acc: 0.941
# starting round 13
# clients:  [91 44 93 64  9 89 59 34 96 28]
# round 13, starting client 1/10, id: 91
# round 13, starting client 2/10, id: 44
# round 13, starting client 3/10, id: 93
# round 13, starting client 4/10, id: 64
# round 13, starting client 5/10, id: 9
# round 13, starting client 6/10, id: 89
# round 13, starting client 7/10, id: 59
# round 13, starting client 8/10, id: 34
# round 13, starting client 9/10, id: 96
# round 13, starting client 10/10, id: 28
# round 13, validation acc: 0.9438
# starting round 14
# clients:  [92 37 83  0 28 95 51 44 21 30]
# round 14, starting client 1/10, id: 92
# round 14, starting client 2/10, id: 37
# round 14, starting client 3/10, id: 83
# round 14, starting client 4/10, id: 0
# round 14, starting client 5/10, id: 28
# round 14, starting client 6/10, id: 95
# round 14, starting client 7/10, id: 51
# round 14, starting client 8/10, id: 44
# round 14, starting client 9/10, id: 21
# round 14, starting client 10/10, id: 30
# round 14, validation acc: 0.9457
# starting round 15
# clients:  [30  9 15 74 75 38 20 41 85 22]
# round 15, starting client 1/10, id: 30
# round 15, starting client 2/10, id: 9
# round 15, starting client 3/10, id: 15
# round 15, starting client 4/10, id: 74
# round 15, starting client 5/10, id: 75
# round 15, starting client 6/10, id: 38
# round 15, starting client 7/10, id: 20
# round 15, starting client 8/10, id: 41
# round 15, starting client 9/10, id: 85
# round 15, starting client 10/10, id: 22
# round 15, validation acc: 0.9478
# starting round 16
# clients:  [66 79 78 73 72  8  4 29 82 76]
# round 16, starting client 1/10, id: 66
# round 16, starting client 2/10, id: 79
# round 16, starting client 3/10, id: 78
# round 16, starting client 4/10, id: 73
# round 16, starting client 5/10, id: 72
# round 16, starting client 6/10, id: 8
# round 16, starting client 7/10, id: 4
# round 16, starting client 8/10, id: 29
# round 16, starting client 9/10, id: 82
# round 16, starting client 10/10, id: 76
# round 16, validation acc: 0.9482
# starting round 17
# clients:  [46 90 93 92 96 91 88 94 62 48]
# round 17, starting client 1/10, id: 46
# round 17, starting client 2/10, id: 90
# round 17, starting client 3/10, id: 93
# round 17, starting client 4/10, id: 92
# round 17, starting client 5/10, id: 96
# round 17, starting client 6/10, id: 91
# round 17, starting client 7/10, id: 88
# round 17, starting client 8/10, id: 94
# round 17, starting client 9/10, id: 62
# round 17, starting client 10/10, id: 48
# round 17, validation acc: 0.952
# starting round 18
# clients:  [66 90 96 14 51 12 19 71 74 69]
# round 18, starting client 1/10, id: 66
# round 18, starting client 2/10, id: 90
# round 18, starting client 3/10, id: 96
# round 18, starting client 4/10, id: 14
# round 18, starting client 5/10, id: 51
# round 18, starting client 6/10, id: 12
# round 18, starting client 7/10, id: 19
# round 18, starting client 8/10, id: 71
# round 18, starting client 9/10, id: 74
# round 18, starting client 10/10, id: 69
# round 18, validation acc: 0.9515
# starting round 19
# clients:  [39 21 60 83 79 76 19 53 71 25]
# round 19, starting client 1/10, id: 39
# round 19, starting client 2/10, id: 21
# round 19, starting client 3/10, id: 60
# round 19, starting client 4/10, id: 83
# round 19, starting client 5/10, id: 79
# round 19, starting client 6/10, id: 76
# round 19, starting client 7/10, id: 19
# round 19, starting client 8/10, id: 53
# round 19, starting client 9/10, id: 71
# round 19, starting client 10/10, id: 25
# round 19, validation acc: 0.9524
# starting round 20
# clients:  [45 99 21 76  2 51 66 14 80 97]
# round 20, starting client 1/10, id: 45
# round 20, starting client 2/10, id: 99
# round 20, starting client 3/10, id: 21
# round 20, starting client 4/10, id: 76
# round 20, starting client 5/10, id: 2
# round 20, starting client 6/10, id: 51
# round 20, starting client 7/10, id: 66
# round 20, starting client 8/10, id: 14
# round 20, starting client 9/10, id: 80
# round 20, starting client 10/10, id: 97
# round 20, validation acc: 0.9529
# starting round 21
# clients:  [ 7 73 90 66 26 75 25 24 28 35]
# round 21, starting client 1/10, id: 7
# round 21, starting client 2/10, id: 73
# round 21, starting client 3/10, id: 90
# round 21, starting client 4/10, id: 66
# round 21, starting client 5/10, id: 26
# round 21, starting client 6/10, id: 75
# round 21, starting client 7/10, id: 25
# round 21, starting client 8/10, id: 24
# round 21, starting client 9/10, id: 28
# round 21, starting client 10/10, id: 35
# round 21, validation acc: 0.9543
# starting round 22
# clients:  [99  7 66  5 24 76 88 87 64 44]
# round 22, starting client 1/10, id: 99
# round 22, starting client 2/10, id: 7
# round 22, starting client 3/10, id: 66
# round 22, starting client 4/10, id: 5
# round 22, starting client 5/10, id: 24
# round 22, starting client 6/10, id: 76
# round 22, starting client 7/10, id: 88
# round 22, starting client 8/10, id: 87
# round 22, starting client 9/10, id: 64
# round 22, starting client 10/10, id: 44
# round 22, validation acc: 0.9542
# starting round 23
# clients:  [ 2 70 28 82 92 19  0 83 12 39]
# round 23, starting client 1/10, id: 2
# round 23, starting client 2/10, id: 70
# round 23, starting client 3/10, id: 28
# round 23, starting client 4/10, id: 82
# round 23, starting client 5/10, id: 92
# round 23, starting client 6/10, id: 19
# round 23, starting client 7/10, id: 0
# round 23, starting client 8/10, id: 83
# round 23, starting client 9/10, id: 12
# round 23, starting client 10/10, id: 39
# round 23, validation acc: 0.9577
# starting round 24
# clients:  [86 84 98 35 63 48 21 97 39 81]
# round 24, starting client 1/10, id: 86
# round 24, starting client 2/10, id: 84
# round 24, starting client 3/10, id: 98
# round 24, starting client 4/10, id: 35
# round 24, starting client 5/10, id: 63
# round 24, starting client 6/10, id: 48
# round 24, starting client 7/10, id: 21
# round 24, starting client 8/10, id: 97
# round 24, starting client 9/10, id: 39
# round 24, starting client 10/10, id: 81
# round 24, validation acc: 0.957
# starting round 25
# clients:  [97 16 90 99 38 63 25 54 56 79]
# round 25, starting client 1/10, id: 97
# round 25, starting client 2/10, id: 16
# round 25, starting client 3/10, id: 90
# round 25, starting client 4/10, id: 99
# round 25, starting client 5/10, id: 38
# round 25, starting client 6/10, id: 63
# round 25, starting client 7/10, id: 25
# round 25, starting client 8/10, id: 54
# round 25, starting client 9/10, id: 56
# round 25, starting client 10/10, id: 79
# round 25, validation acc: 0.9599
# starting round 26
# clients:  [44  7 97 41  8 74 65 70 69 88]
# round 26, starting client 1/10, id: 44
# round 26, starting client 2/10, id: 7
# round 26, starting client 3/10, id: 97
# round 26, starting client 4/10, id: 41
# round 26, starting client 5/10, id: 8
# round 26, starting client 6/10, id: 74
# round 26, starting client 7/10, id: 65
# round 26, starting client 8/10, id: 70
# round 26, starting client 9/10, id: 69
# round 26, starting client 10/10, id: 88
# round 26, validation acc: 0.9577
# starting round 27
# clients:  [ 9 87 74 64 88 61 39 59 41 67]
# round 27, starting client 1/10, id: 9
# round 27, starting client 2/10, id: 87
# round 27, starting client 3/10, id: 74
# round 27, starting client 4/10, id: 64
# round 27, starting client 5/10, id: 88
# round 27, starting client 6/10, id: 61
# round 27, starting client 7/10, id: 39
# round 27, starting client 8/10, id: 59
# round 27, starting client 9/10, id: 41
# round 27, starting client 10/10, id: 67
# round 27, validation acc: 0.9602
# starting round 28
# clients:  [ 4 73 24 57 23 70 16 97 32 42]
# round 28, starting client 1/10, id: 4
# round 28, starting client 2/10, id: 73
# round 28, starting client 3/10, id: 24
# round 28, starting client 4/10, id: 57
# round 28, starting client 5/10, id: 23
# round 28, starting client 6/10, id: 70
# round 28, starting client 7/10, id: 16
# round 28, starting client 8/10, id: 97
# round 28, starting client 9/10, id: 32
# round 28, starting client 10/10, id: 42
# round 28, validation acc: 0.9629
# starting round 29
# clients:  [19 71 30 91 32 70 90 49 36 98]
# round 29, starting client 1/10, id: 19
# round 29, starting client 2/10, id: 71
# round 29, starting client 3/10, id: 30
# round 29, starting client 4/10, id: 91
# round 29, starting client 5/10, id: 32
# round 29, starting client 6/10, id: 70
# round 29, starting client 7/10, id: 90
# round 29, starting client 8/10, id: 49
# round 29, starting client 9/10, id: 36
# round 29, starting client 10/10, id: 98
# round 29, validation acc: 0.9613
# starting round 30
# clients:  [84 66 29 79 77 46 58 35 33  8]
# round 30, starting client 1/10, id: 84
# round 30, starting client 2/10, id: 66
# round 30, starting client 3/10, id: 29
# round 30, starting client 4/10, id: 79
# round 30, starting client 5/10, id: 77
# round 30, starting client 6/10, id: 46
# round 30, starting client 7/10, id: 58
# round 30, starting client 8/10, id: 35
# round 30, starting client 9/10, id: 33
# round 30, starting client 10/10, id: 8
# round 30, validation acc: 0.9639
# starting round 31
# clients:  [90 80 44 15  4 91  2 78 33  0]
# round 31, starting client 1/10, id: 90
# round 31, starting client 2/10, id: 80
# round 31, starting client 3/10, id: 44
# round 31, starting client 4/10, id: 15
# round 31, starting client 5/10, id: 4
# round 31, starting client 6/10, id: 91
# round 31, starting client 7/10, id: 2
# round 31, starting client 8/10, id: 78
# round 31, starting client 9/10, id: 33
# round 31, starting client 10/10, id: 0
# round 31, validation acc: 0.9624
# starting round 32
# clients:  [ 0 81 76 23 29 58 94 14 91 15]
# round 32, starting client 1/10, id: 0
# round 32, starting client 2/10, id: 81
# round 32, starting client 3/10, id: 76
# round 32, starting client 4/10, id: 23
# round 32, starting client 5/10, id: 29
# round 32, starting client 6/10, id: 58
# round 32, starting client 7/10, id: 94
# round 32, starting client 8/10, id: 14
# round 32, starting client 9/10, id: 91
# round 32, starting client 10/10, id: 15
# round 32, validation acc: 0.964
# starting round 33
# clients:  [31 22 49 98 73  1 24 17 30 76]
# round 33, starting client 1/10, id: 31
# round 33, starting client 2/10, id: 22
# round 33, starting client 3/10, id: 49
# round 33, starting client 4/10, id: 98
# round 33, starting client 5/10, id: 73
# round 33, starting client 6/10, id: 1
# round 33, starting client 7/10, id: 24
# round 33, starting client 8/10, id: 17
# round 33, starting client 9/10, id: 30
# round 33, starting client 10/10, id: 76
# round 33, validation acc: 0.9635
# starting round 34
# clients:  [22 20 12 76 97 35 57  2 18 36]
# round 34, starting client 1/10, id: 22
# round 34, starting client 2/10, id: 20
# round 34, starting client 3/10, id: 12
# round 34, starting client 4/10, id: 76
# round 34, starting client 5/10, id: 97
# round 34, starting client 6/10, id: 35
# round 34, starting client 7/10, id: 57
# round 34, starting client 8/10, id: 2
# round 34, starting client 9/10, id: 18
# round 34, starting client 10/10, id: 36
# round 34, validation acc: 0.9634
# starting round 35
# clients:  [19 51 72 84  3 45 49 53 26 64]
# round 35, starting client 1/10, id: 19
# round 35, starting client 2/10, id: 51
# round 35, starting client 3/10, id: 72
# round 35, starting client 4/10, id: 84
# round 35, starting client 5/10, id: 3
# round 35, starting client 6/10, id: 45
# round 35, starting client 7/10, id: 49
# round 35, starting client 8/10, id: 53
# round 35, starting client 9/10, id: 26
# round 35, starting client 10/10, id: 64
# round 35, validation acc: 0.964
# starting round 36
# clients:  [ 0 17 31 35 60 48 58  6 38 93]
# round 36, starting client 1/10, id: 0
# round 36, starting client 2/10, id: 17
# round 36, starting client 3/10, id: 31
# round 36, starting client 4/10, id: 35
# round 36, starting client 5/10, id: 60
# round 36, starting client 6/10, id: 48
# round 36, starting client 7/10, id: 58
# round 36, starting client 8/10, id: 6
# round 36, starting client 9/10, id: 38
# round 36, starting client 10/10, id: 93
# round 36, validation acc: 0.9654
# starting round 37
# clients:  [15 92 21 86 61 83 13  3 99 52]
# round 37, starting client 1/10, id: 15
# round 37, starting client 2/10, id: 92
# round 37, starting client 3/10, id: 21
# round 37, starting client 4/10, id: 86
# round 37, starting client 5/10, id: 61
# round 37, starting client 6/10, id: 83
# round 37, starting client 7/10, id: 13
# round 37, starting client 8/10, id: 3
# round 37, starting client 9/10, id: 99
# round 37, starting client 10/10, id: 52
# round 37, validation acc: 0.9654
# starting round 38
# clients:  [18 45 38 21 10 41 59 96 60 72]
# round 38, starting client 1/10, id: 18
# round 38, starting client 2/10, id: 45
# round 38, starting client 3/10, id: 38
# round 38, starting client 4/10, id: 21
# round 38, starting client 5/10, id: 10
# round 38, starting client 6/10, id: 41
# round 38, starting client 7/10, id: 59
# round 38, starting client 8/10, id: 96
# round 38, starting client 9/10, id: 60
# round 38, starting client 10/10, id: 72
# round 38, validation acc: 0.9671
# starting round 39
# clients:  [28 95 67 82 33 61 79 16 72  7]
# round 39, starting client 1/10, id: 28
# round 39, starting client 2/10, id: 95
# round 39, starting client 3/10, id: 67
# round 39, starting client 4/10, id: 82
# round 39, starting client 5/10, id: 33
# round 39, starting client 6/10, id: 61
# round 39, starting client 7/10, id: 79
# round 39, starting client 8/10, id: 16
# round 39, starting client 9/10, id: 72
# round 39, starting client 10/10, id: 7
# round 39, validation acc: 0.9674
# starting round 40
# clients:  [ 4 26  1 31 86  3 34 15  8 87]
# round 40, starting client 1/10, id: 4
# round 40, starting client 2/10, id: 26
# round 40, starting client 3/10, id: 1
# round 40, starting client 4/10, id: 31
# round 40, starting client 5/10, id: 86
# round 40, starting client 6/10, id: 3
# round 40, starting client 7/10, id: 34
# round 40, starting client 8/10, id: 15
# round 40, starting client 9/10, id: 8
# round 40, starting client 10/10, id: 87
# round 40, validation acc: 0.9687
# starting round 41
# clients:  [94 74 78 79 53 37 17 85 64 91]
# round 41, starting client 1/10, id: 94
# round 41, starting client 2/10, id: 74
# round 41, starting client 3/10, id: 78
# round 41, starting client 4/10, id: 79
# round 41, starting client 5/10, id: 53
# round 41, starting client 6/10, id: 37
# round 41, starting client 7/10, id: 17
# round 41, starting client 8/10, id: 85
# round 41, starting client 9/10, id: 64
# round 41, starting client 10/10, id: 91
# round 41, validation acc: 0.97
# starting round 42
# clients:  [68 61 67 47 78 84 70 15 19 93]
# round 42, starting client 1/10, id: 68
# round 42, starting client 2/10, id: 61
# round 42, starting client 3/10, id: 67
# round 42, starting client 4/10, id: 47
# round 42, starting client 5/10, id: 78
# round 42, starting client 6/10, id: 84
# round 42, starting client 7/10, id: 70
# round 42, starting client 8/10, id: 15
# round 42, starting client 9/10, id: 19
# round 42, starting client 10/10, id: 93
# round 42, validation acc: 0.9704
# starting round 43
# clients:  [73 75 17 27 94 81 84 32 19 64]
# round 43, starting client 1/10, id: 73
# round 43, starting client 2/10, id: 75
# round 43, starting client 3/10, id: 17
# round 43, starting client 4/10, id: 27
# round 43, starting client 5/10, id: 94
# round 43, starting client 6/10, id: 81
# round 43, starting client 7/10, id: 84
# round 43, starting client 8/10, id: 32
# round 43, starting client 9/10, id: 19
# round 43, starting client 10/10, id: 64
# round 43, validation acc: 0.9704
# starting round 44
# clients:  [73 96 48 50 28 87 54 80  8 10]
# round 44, starting client 1/10, id: 73
# round 44, starting client 2/10, id: 96
# round 44, starting client 3/10, id: 48
# round 44, starting client 4/10, id: 50
# round 44, starting client 5/10, id: 28
# round 44, starting client 6/10, id: 87
# round 44, starting client 7/10, id: 54
# round 44, starting client 8/10, id: 80
# round 44, starting client 9/10, id: 8
# round 44, starting client 10/10, id: 10
# round 44, validation acc: 0.9698
# starting round 45
# clients:  [50 62 47 23  6 48 59 21  2 63]
# round 45, starting client 1/10, id: 50
# round 45, starting client 2/10, id: 62
# round 45, starting client 3/10, id: 47
# round 45, starting client 4/10, id: 23
# round 45, starting client 5/10, id: 6
# round 45, starting client 6/10, id: 48
# round 45, starting client 7/10, id: 59
# round 45, starting client 8/10, id: 21
# round 45, starting client 9/10, id: 2
# round 45, starting client 10/10, id: 63
# round 45, validation acc: 0.9709
# starting round 46
# clients:  [ 8 53 16 19 71 92 48 37 67 46]
# round 46, starting client 1/10, id: 8
# round 46, starting client 2/10, id: 53
# round 46, starting client 3/10, id: 16
# round 46, starting client 4/10, id: 19
# round 46, starting client 5/10, id: 71
# round 46, starting client 6/10, id: 92
# round 46, starting client 7/10, id: 48
# round 46, starting client 8/10, id: 37
# round 46, starting client 9/10, id: 67
# round 46, starting client 10/10, id: 46
# round 46, validation acc: 0.9708
# starting round 47
# clients:  [61 86 31 41 26 97 53 85 74 16]
# round 47, starting client 1/10, id: 61
# round 47, starting client 2/10, id: 86
# round 47, starting client 3/10, id: 31
# round 47, starting client 4/10, id: 41
# round 47, starting client 5/10, id: 26
# round 47, starting client 6/10, id: 97
# round 47, starting client 7/10, id: 53
# round 47, starting client 8/10, id: 85
# round 47, starting client 9/10, id: 74
# round 47, starting client 10/10, id: 16
# round 47, validation acc: 0.9711
# starting round 48
# clients:  [53 27 10  3 52 83 39 43  7 44]
# round 48, starting client 1/10, id: 53
# round 48, starting client 2/10, id: 27
# round 48, starting client 3/10, id: 10
# round 48, starting client 4/10, id: 3
# round 48, starting client 5/10, id: 52
# round 48, starting client 6/10, id: 83
# round 48, starting client 7/10, id: 39
# round 48, starting client 8/10, id: 43
# round 48, starting client 9/10, id: 7
# round 48, starting client 10/10, id: 44
# round 48, validation acc: 0.9708
# starting round 49
# clients:  [22 15 47 14 80 46  7 74 78 51]
# round 49, starting client 1/10, id: 22
# round 49, starting client 2/10, id: 15
# round 49, starting client 3/10, id: 47
# round 49, starting client 4/10, id: 14
# round 49, starting client 5/10, id: 80
# round 49, starting client 6/10, id: 46
# round 49, starting client 7/10, id: 7
# round 49, starting client 8/10, id: 74
# round 49, starting client 9/10, id: 78
# round 49, starting client 10/10, id: 51
# round 49, validation acc: 0.9719
# starting round 50
# clients:  [71 14 89 28 56 63 86 74 81 58]
# round 50, starting client 1/10, id: 71
# round 50, starting client 2/10, id: 14
# round 50, starting client 3/10, id: 89
# round 50, starting client 4/10, id: 28
# round 50, starting client 5/10, id: 56
# round 50, starting client 6/10, id: 63
# round 50, starting client 7/10, id: 86
# round 50, starting client 8/10, id: 74
# round 50, starting client 9/10, id: 81
# round 50, starting client 10/10, id: 58
# round 50, validation acc: 0.9713
# starting round 51
# clients:  [38 75 10 70  3 20 30 17 27 55]
# round 51, starting client 1/10, id: 38
# round 51, starting client 2/10, id: 75
# round 51, starting client 3/10, id: 10
# round 51, starting client 4/10, id: 70
# round 51, starting client 5/10, id: 3
# round 51, starting client 6/10, id: 20
# round 51, starting client 7/10, id: 30
# round 51, starting client 8/10, id: 17
# round 51, starting client 9/10, id: 27
# round 51, starting client 10/10, id: 55
# round 51, validation acc: 0.9709
# starting round 52
# clients:  [89 92 28 61 51 71 18 31  2 13]
# round 52, starting client 1/10, id: 89
# round 52, starting client 2/10, id: 92
# round 52, starting client 3/10, id: 28
# round 52, starting client 4/10, id: 61
# round 52, starting client 5/10, id: 51
# round 52, starting client 6/10, id: 71
# round 52, starting client 7/10, id: 18
# round 52, starting client 8/10, id: 31
# round 52, starting client 9/10, id: 2
# round 52, starting client 10/10, id: 13
# round 52, validation acc: 0.9722
# starting round 53
# clients:  [66  1 26 57 89  8 39 16  0 99]
# round 53, starting client 1/10, id: 66
# round 53, starting client 2/10, id: 1
# round 53, starting client 3/10, id: 26
# round 53, starting client 4/10, id: 57
# round 53, starting client 5/10, id: 89
# round 53, starting client 6/10, id: 8
# round 53, starting client 7/10, id: 39
# round 53, starting client 8/10, id: 16
# round 53, starting client 9/10, id: 0
# round 53, starting client 10/10, id: 99
# round 53, validation acc: 0.9731
# starting round 54
# clients:  [98 44 16 86 96 45 13 78 15 39]
# round 54, starting client 1/10, id: 98
# round 54, starting client 2/10, id: 44
# round 54, starting client 3/10, id: 16
# round 54, starting client 4/10, id: 86
# round 54, starting client 5/10, id: 96
# round 54, starting client 6/10, id: 45
# round 54, starting client 7/10, id: 13
# round 54, starting client 8/10, id: 78
# round 54, starting client 9/10, id: 15
# round 54, starting client 10/10, id: 39
# round 54, validation acc: 0.9733
# starting round 55
# clients:  [94 20 93  5 95 80 89 11  2 48]
# round 55, starting client 1/10, id: 94
# round 55, starting client 2/10, id: 20
# round 55, starting client 3/10, id: 93
# round 55, starting client 4/10, id: 5
# round 55, starting client 5/10, id: 95
# round 55, starting client 6/10, id: 80
# round 55, starting client 7/10, id: 89
# round 55, starting client 8/10, id: 11
# round 55, starting client 9/10, id: 2
# round 55, starting client 10/10, id: 48
# round 55, validation acc: 0.9735
# starting round 56
# clients:  [75 79  5 34 89 44 10  0 82  4]
# round 56, starting client 1/10, id: 75
# round 56, starting client 2/10, id: 79
# round 56, starting client 3/10, id: 5
# round 56, starting client 4/10, id: 34
# round 56, starting client 5/10, id: 89
# round 56, starting client 6/10, id: 44
# round 56, starting client 7/10, id: 10
# round 56, starting client 8/10, id: 0
# round 56, starting client 9/10, id: 82
# round 56, starting client 10/10, id: 4
# round 56, validation acc: 0.9736
# starting round 57
# clients:  [50 92 78 11 82 87 94 93 59 74]
# round 57, starting client 1/10, id: 50
# round 57, starting client 2/10, id: 92
# round 57, starting client 3/10, id: 78
# round 57, starting client 4/10, id: 11
# round 57, starting client 5/10, id: 82
# round 57, starting client 6/10, id: 87
# round 57, starting client 7/10, id: 94
# round 57, starting client 8/10, id: 93
# round 57, starting client 9/10, id: 59
# round 57, starting client 10/10, id: 74
# round 57, validation acc: 0.9728
# starting round 58
# clients:  [ 9  4 97 84  2 36 20  5 79  0]
# round 58, starting client 1/10, id: 9
# round 58, starting client 2/10, id: 4
# round 58, starting client 3/10, id: 97
# round 58, starting client 4/10, id: 84
# round 58, starting client 5/10, id: 2
# round 58, starting client 6/10, id: 36
# round 58, starting client 7/10, id: 20
# round 58, starting client 8/10, id: 5
# round 58, starting client 9/10, id: 79
# round 58, starting client 10/10, id: 0
# round 58, validation acc: 0.9734
# starting round 59
# clients:  [58 47 29 99  6 69  7 53 81 45]
# round 59, starting client 1/10, id: 58
# round 59, starting client 2/10, id: 47
# round 59, starting client 3/10, id: 29
# round 59, starting client 4/10, id: 99
# round 59, starting client 5/10, id: 6
# round 59, starting client 6/10, id: 69
# round 59, starting client 7/10, id: 7
# round 59, starting client 8/10, id: 53
# round 59, starting client 9/10, id: 81
# round 59, starting client 10/10, id: 45
# round 59, validation acc: 0.9749
# starting round 60
# clients:  [55 94  0 82 81 83 66 39 54  4]
# round 60, starting client 1/10, id: 55
# round 60, starting client 2/10, id: 94
# round 60, starting client 3/10, id: 0
# round 60, starting client 4/10, id: 82
# round 60, starting client 5/10, id: 81
# round 60, starting client 6/10, id: 83
# round 60, starting client 7/10, id: 66
# round 60, starting client 8/10, id: 39
# round 60, starting client 9/10, id: 54
# round 60, starting client 10/10, id: 4
# round 60, validation acc: 0.9747
# starting round 61
# clients:  [11  2 61 33 87 53 88 94 39 80]
# round 61, starting client 1/10, id: 11
# round 61, starting client 2/10, id: 2
# round 61, starting client 3/10, id: 61
# round 61, starting client 4/10, id: 33
# round 61, starting client 5/10, id: 87
# round 61, starting client 6/10, id: 53
# round 61, starting client 7/10, id: 88
# round 61, starting client 8/10, id: 94
# round 61, starting client 9/10, id: 39
# round 61, starting client 10/10, id: 80
# round 61, validation acc: 0.9751
# starting round 62
# clients:  [96  2 13 89 57 77 73 87 55 70]
# round 62, starting client 1/10, id: 96
# round 62, starting client 2/10, id: 2
# round 62, starting client 3/10, id: 13
# round 62, starting client 4/10, id: 89
# round 62, starting client 5/10, id: 57
# round 62, starting client 6/10, id: 77
# round 62, starting client 7/10, id: 73
# round 62, starting client 8/10, id: 87
# round 62, starting client 9/10, id: 55
# round 62, starting client 10/10, id: 70
# round 62, validation acc: 0.9759
# starting round 63
# clients:  [ 3 45 89 57 58 59 18 29 31 44]
# round 63, starting client 1/10, id: 3
# round 63, starting client 2/10, id: 45
# round 63, starting client 3/10, id: 89
# round 63, starting client 4/10, id: 57
# round 63, starting client 5/10, id: 58
# round 63, starting client 6/10, id: 59
# round 63, starting client 7/10, id: 18
# round 63, starting client 8/10, id: 29
# round 63, starting client 9/10, id: 31
# round 63, starting client 10/10, id: 44
# round 63, validation acc: 0.9762
# starting round 64
# clients:  [94 49 65  6 30  7 63 91 98 97]
# round 64, starting client 1/10, id: 94
# round 64, starting client 2/10, id: 49
# round 64, starting client 3/10, id: 65
# round 64, starting client 4/10, id: 6
# round 64, starting client 5/10, id: 30
# round 64, starting client 6/10, id: 7
# round 64, starting client 7/10, id: 63
# round 64, starting client 8/10, id: 91
# round 64, starting client 9/10, id: 98
# round 64, starting client 10/10, id: 97
# round 64, validation acc: 0.9748
# starting round 65
# clients:  [89 65 94 61 45 87  2 57 13 18]
# round 65, starting client 1/10, id: 89
# round 65, starting client 2/10, id: 65
# round 65, starting client 3/10, id: 94
# round 65, starting client 4/10, id: 61
# round 65, starting client 5/10, id: 45
# round 65, starting client 6/10, id: 87
# round 65, starting client 7/10, id: 2
# round 65, starting client 8/10, id: 57
# round 65, starting client 9/10, id: 13
# round 65, starting client 10/10, id: 18
# round 65, validation acc: 0.9758
# starting round 66
# clients:  [74 65 23 50 98 85 63 30 71 28]
# round 66, starting client 1/10, id: 74
# round 66, starting client 2/10, id: 65
# round 66, starting client 3/10, id: 23
# round 66, starting client 4/10, id: 50
# round 66, starting client 5/10, id: 98
# round 66, starting client 6/10, id: 85
# round 66, starting client 7/10, id: 63
# round 66, starting client 8/10, id: 30
# round 66, starting client 9/10, id: 71
# round 66, starting client 10/10, id: 28
# round 66, validation acc: 0.9769
# starting round 67
# clients:  [99 87 67 24 14 48 21 84 91  7]
# round 67, starting client 1/10, id: 99
# round 67, starting client 2/10, id: 87
# round 67, starting client 3/10, id: 67
# round 67, starting client 4/10, id: 24
# round 67, starting client 5/10, id: 14
# round 67, starting client 6/10, id: 48
# round 67, starting client 7/10, id: 21
# round 67, starting client 8/10, id: 84
# round 67, starting client 9/10, id: 91
# round 67, starting client 10/10, id: 7
# round 67, validation acc: 0.9763
# starting round 68
# clients:  [58 10  8  7 26  2  5 49  4 84]
# round 68, starting client 1/10, id: 58
# round 68, starting client 2/10, id: 10
# round 68, starting client 3/10, id: 8
# round 68, starting client 4/10, id: 7
# round 68, starting client 5/10, id: 26
# round 68, starting client 6/10, id: 2
# round 68, starting client 7/10, id: 5
# round 68, starting client 8/10, id: 49
# round 68, starting client 9/10, id: 4
# round 68, starting client 10/10, id: 84
# round 68, validation acc: 0.9756
# starting round 69
# clients:  [19 90 31 93 47 28 20 80 64 92]
# round 69, starting client 1/10, id: 19
# round 69, starting client 2/10, id: 90
# round 69, starting client 3/10, id: 31
# round 69, starting client 4/10, id: 93
# round 69, starting client 5/10, id: 47
# round 69, starting client 6/10, id: 28
# round 69, starting client 7/10, id: 20
# round 69, starting client 8/10, id: 80
# round 69, starting client 9/10, id: 64
# round 69, starting client 10/10, id: 92
# round 69, validation acc: 0.9755
# starting round 70
# clients:  [99 77 53 81 85  3 27 65 80 75]
# round 70, starting client 1/10, id: 99
# round 70, starting client 2/10, id: 77
# round 70, starting client 3/10, id: 53
# round 70, starting client 4/10, id: 81
# round 70, starting client 5/10, id: 85
# round 70, starting client 6/10, id: 3
# round 70, starting client 7/10, id: 27
# round 70, starting client 8/10, id: 65
# round 70, starting client 9/10, id: 80
# round 70, starting client 10/10, id: 75
# round 70, validation acc: 0.9766
# starting round 71
# clients:  [30  0 13  3 85 74 55 77 16  1]
# round 71, starting client 1/10, id: 30
# round 71, starting client 2/10, id: 0
# round 71, starting client 3/10, id: 13
# round 71, starting client 4/10, id: 3
# round 71, starting client 5/10, id: 85
# round 71, starting client 6/10, id: 74
# round 71, starting client 7/10, id: 55
# round 71, starting client 8/10, id: 77
# round 71, starting client 9/10, id: 16
# round 71, starting client 10/10, id: 1
# round 71, validation acc: 0.9771
# starting round 72
# clients:  [35 10 38 98 63 22 59 33  6 71]
# round 72, starting client 1/10, id: 35
# round 72, starting client 2/10, id: 10
# round 72, starting client 3/10, id: 38
# round 72, starting client 4/10, id: 98
# round 72, starting client 5/10, id: 63
# round 72, starting client 6/10, id: 22
# round 72, starting client 7/10, id: 59
# round 72, starting client 8/10, id: 33
# round 72, starting client 9/10, id: 6
# round 72, starting client 10/10, id: 71
# round 72, validation acc: 0.9758
# starting round 73
# clients:  [20  8 87 27 35 69 34 93  2 43]
# round 73, starting client 1/10, id: 20
# round 73, starting client 2/10, id: 8
# round 73, starting client 3/10, id: 87
# round 73, starting client 4/10, id: 27
# round 73, starting client 5/10, id: 35
# round 73, starting client 6/10, id: 69
# round 73, starting client 7/10, id: 34
# round 73, starting client 8/10, id: 93
# round 73, starting client 9/10, id: 2
# round 73, starting client 10/10, id: 43
# round 73, validation acc: 0.9751
# starting round 74
# clients:  [40 76 89  4 30 11 58 86 23 46]
# round 74, starting client 1/10, id: 40
# round 74, starting client 2/10, id: 76
# round 74, starting client 3/10, id: 89
# round 74, starting client 4/10, id: 4
# round 74, starting client 5/10, id: 30
# round 74, starting client 6/10, id: 11
# round 74, starting client 7/10, id: 58
# round 74, starting client 8/10, id: 86
# round 74, starting client 9/10, id: 23
# round 74, starting client 10/10, id: 46
# round 74, validation acc: 0.9773
# starting round 75
# clients:  [98 52 11  4 14 66 16 19 92 78]
# round 75, starting client 1/10, id: 98
# round 75, starting client 2/10, id: 52
# round 75, starting client 3/10, id: 11
# round 75, starting client 4/10, id: 4
# round 75, starting client 5/10, id: 14
# round 75, starting client 6/10, id: 66
# round 75, starting client 7/10, id: 16
# round 75, starting client 8/10, id: 19
# round 75, starting client 9/10, id: 92
# round 75, starting client 10/10, id: 78
# round 75, validation acc: 0.9768
# starting round 76
# clients:  [78 18 28 39 36  9 49 99 81 31]
# round 76, starting client 1/10, id: 78
# round 76, starting client 2/10, id: 18
# round 76, starting client 3/10, id: 28
# round 76, starting client 4/10, id: 39
# round 76, starting client 5/10, id: 36
# round 76, starting client 6/10, id: 9
# round 76, starting client 7/10, id: 49
# round 76, starting client 8/10, id: 99
# round 76, starting client 9/10, id: 81
# round 76, starting client 10/10, id: 31
# round 76, validation acc: 0.9776
# starting round 77
# clients:  [46 53  8 13 92 29 62 79 81 70]
# round 77, starting client 1/10, id: 46
# round 77, starting client 2/10, id: 53
# round 77, starting client 3/10, id: 8
# round 77, starting client 4/10, id: 13
# round 77, starting client 5/10, id: 92
# round 77, starting client 6/10, id: 29
# round 77, starting client 7/10, id: 62
# round 77, starting client 8/10, id: 79
# round 77, starting client 9/10, id: 81
# round 77, starting client 10/10, id: 70
# round 77, validation acc: 0.9769
# starting round 78
# clients:  [54  1  6 59 88 36 22 20 76 26]
# round 78, starting client 1/10, id: 54
# round 78, starting client 2/10, id: 1
# round 78, starting client 3/10, id: 6
# round 78, starting client 4/10, id: 59
# round 78, starting client 5/10, id: 88
# round 78, starting client 6/10, id: 36
# round 78, starting client 7/10, id: 22
# round 78, starting client 8/10, id: 20
# round 78, starting client 9/10, id: 76
# round 78, starting client 10/10, id: 26
# round 78, validation acc: 0.9763
# starting round 79
# clients:  [72  1 65  7 87 80 69 19 60  0]
# round 79, starting client 1/10, id: 72
# round 79, starting client 2/10, id: 1
# round 79, starting client 3/10, id: 65
# round 79, starting client 4/10, id: 7
# round 79, starting client 5/10, id: 87
# round 79, starting client 6/10, id: 80
# round 79, starting client 7/10, id: 69
# round 79, starting client 8/10, id: 19
# round 79, starting client 9/10, id: 60
# round 79, starting client 10/10, id: 0
# round 79, validation acc: 0.9765
# starting round 80
# clients:  [56 62 30 17 50 40 58 51 78 60]
# round 80, starting client 1/10, id: 56
# round 80, starting client 2/10, id: 62
# round 80, starting client 3/10, id: 30
# round 80, starting client 4/10, id: 17
# round 80, starting client 5/10, id: 50
# round 80, starting client 6/10, id: 40
# round 80, starting client 7/10, id: 58
# round 80, starting client 8/10, id: 51
# round 80, starting client 9/10, id: 78
# round 80, starting client 10/10, id: 60
# round 80, validation acc: 0.9773
# starting round 81
# clients:  [30 43 68 44 59  4 41 15 87  2]
# round 81, starting client 1/10, id: 30
# round 81, starting client 2/10, id: 43
# round 81, starting client 3/10, id: 68
# round 81, starting client 4/10, id: 44
# round 81, starting client 5/10, id: 59
# round 81, starting client 6/10, id: 4
# round 81, starting client 7/10, id: 41
# round 81, starting client 8/10, id: 15
# round 81, starting client 9/10, id: 87
# round 81, starting client 10/10, id: 2
# round 81, validation acc: 0.9763
# starting round 82
# clients:  [73 48 91 98 16 46 41 55 40 39]
# round 82, starting client 1/10, id: 73
# round 82, starting client 2/10, id: 48
# round 82, starting client 3/10, id: 91
# round 82, starting client 4/10, id: 98
# round 82, starting client 5/10, id: 16
# round 82, starting client 6/10, id: 46
# round 82, starting client 7/10, id: 41
# round 82, starting client 8/10, id: 55
# round 82, starting client 9/10, id: 40
# round 82, starting client 10/10, id: 39
# round 82, validation acc: 0.9771
# starting round 83
# clients:  [13 38 17 46 32 71 34  1 58 76]
# round 83, starting client 1/10, id: 13
# round 83, starting client 2/10, id: 38
# round 83, starting client 3/10, id: 17
# round 83, starting client 4/10, id: 46
# round 83, starting client 5/10, id: 32
# round 83, starting client 6/10, id: 71
# round 83, starting client 7/10, id: 34
# round 83, starting client 8/10, id: 1
# round 83, starting client 9/10, id: 58
# round 83, starting client 10/10, id: 76
# round 83, validation acc: 0.9762
# starting round 84
# clients:  [15 89 55 85 78 80 39 88 96 38]
# round 84, starting client 1/10, id: 15
# round 84, starting client 2/10, id: 89
# round 84, starting client 3/10, id: 55
# round 84, starting client 4/10, id: 85
# round 84, starting client 5/10, id: 78
# round 84, starting client 6/10, id: 80
# round 84, starting client 7/10, id: 39
# round 84, starting client 8/10, id: 88
# round 84, starting client 9/10, id: 96
# round 84, starting client 10/10, id: 38
# round 84, validation acc: 0.9765
# starting round 85
# clients:  [79 57  6 29 27 22 16 49  7 38]
# round 85, starting client 1/10, id: 79
# round 85, starting client 2/10, id: 57
# round 85, starting client 3/10, id: 6
# round 85, starting client 4/10, id: 29
# round 85, starting client 5/10, id: 27
# round 85, starting client 6/10, id: 22
# round 85, starting client 7/10, id: 16
# round 85, starting client 8/10, id: 49
# round 85, starting client 9/10, id: 7
# round 85, starting client 10/10, id: 38
# round 85, validation acc: 0.9785
# starting round 86
# clients:  [24 10 28 77 19 26 89 56 46 43]
# round 86, starting client 1/10, id: 24
# round 86, starting client 2/10, id: 10
# round 86, starting client 3/10, id: 28
# round 86, starting client 4/10, id: 77
# round 86, starting client 5/10, id: 19
# round 86, starting client 6/10, id: 26
# round 86, starting client 7/10, id: 89
# round 86, starting client 8/10, id: 56
# round 86, starting client 9/10, id: 46
# round 86, starting client 10/10, id: 43
# round 86, validation acc: 0.9785
# starting round 87
# clients:  [45 28 13 48 58 77 78 39 91 18]
# round 87, starting client 1/10, id: 45
# round 87, starting client 2/10, id: 28
# round 87, starting client 3/10, id: 13
# round 87, starting client 4/10, id: 48
# round 87, starting client 5/10, id: 58
# round 87, starting client 6/10, id: 77
# round 87, starting client 7/10, id: 78
# round 87, starting client 8/10, id: 39
# round 87, starting client 9/10, id: 91
# round 87, starting client 10/10, id: 18
# round 87, validation acc: 0.9769
# starting round 88
# clients:  [13 67 24  4  1 23 94 81 77 48]
# round 88, starting client 1/10, id: 13
# round 88, starting client 2/10, id: 67
# round 88, starting client 3/10, id: 24
# round 88, starting client 4/10, id: 4
# round 88, starting client 5/10, id: 1
# round 88, starting client 6/10, id: 23
# round 88, starting client 7/10, id: 94
# round 88, starting client 8/10, id: 81
# round 88, starting client 9/10, id: 77
# round 88, starting client 10/10, id: 48
# round 88, validation acc: 0.9778
# starting round 89
# clients:  [24  1 50 61 83 46 35 66 71 29]
# round 89, starting client 1/10, id: 24
# round 89, starting client 2/10, id: 1
# round 89, starting client 3/10, id: 50
# round 89, starting client 4/10, id: 61
# round 89, starting client 5/10, id: 83
# round 89, starting client 6/10, id: 46
# round 89, starting client 7/10, id: 35
# round 89, starting client 8/10, id: 66
# round 89, starting client 9/10, id: 71
# round 89, starting client 10/10, id: 29
# round 89, validation acc: 0.9787
# starting round 90
# clients:  [81 11 35 60  7 53 71 29 46 16]
# round 90, starting client 1/10, id: 81
# round 90, starting client 2/10, id: 11
# round 90, starting client 3/10, id: 35
# round 90, starting client 4/10, id: 60
# round 90, starting client 5/10, id: 7
# round 90, starting client 6/10, id: 53
# round 90, starting client 7/10, id: 71
# round 90, starting client 8/10, id: 29
# round 90, starting client 9/10, id: 46
# round 90, starting client 10/10, id: 16
# round 90, validation acc: 0.9794
# starting round 91
# clients:  [58 56 61 41 14 24 96 50  8 42]
# round 91, starting client 1/10, id: 58
# round 91, starting client 2/10, id: 56
# round 91, starting client 3/10, id: 61
# round 91, starting client 4/10, id: 41
# round 91, starting client 5/10, id: 14
# round 91, starting client 6/10, id: 24
# round 91, starting client 7/10, id: 96
# round 91, starting client 8/10, id: 50
# round 91, starting client 9/10, id: 8
# round 91, starting client 10/10, id: 42
# round 91, validation acc: 0.9767
# starting round 92
# clients:  [12  0 71 72 66  9 64 22 85 19]
# round 92, starting client 1/10, id: 12
# round 92, starting client 2/10, id: 0
# round 92, starting client 3/10, id: 71
# round 92, starting client 4/10, id: 72
# round 92, starting client 5/10, id: 66
# round 92, starting client 6/10, id: 9
# round 92, starting client 7/10, id: 64
# round 92, starting client 8/10, id: 22
# round 92, starting client 9/10, id: 85
# round 92, starting client 10/10, id: 19
# round 92, validation acc: 0.9785
# starting round 93
# clients:  [ 3 15 52 31 25 26 10  0 91 40]
# round 93, starting client 1/10, id: 3
# round 93, starting client 2/10, id: 15
# round 93, starting client 3/10, id: 52
# round 93, starting client 4/10, id: 31
# round 93, starting client 5/10, id: 25
# round 93, starting client 6/10, id: 26
# round 93, starting client 7/10, id: 10
# round 93, starting client 8/10, id: 0
# round 93, starting client 9/10, id: 91
# round 93, starting client 10/10, id: 40
# round 93, validation acc: 0.9786
# starting round 94
# clients:  [46 64 55 21 28 85 29 61 30 36]
# round 94, starting client 1/10, id: 46
# round 94, starting client 2/10, id: 64
# round 94, starting client 3/10, id: 55
# round 94, starting client 4/10, id: 21
# round 94, starting client 5/10, id: 28
# round 94, starting client 6/10, id: 85
# round 94, starting client 7/10, id: 29
# round 94, starting client 8/10, id: 61
# round 94, starting client 9/10, id: 30
# round 94, starting client 10/10, id: 36
# round 94, validation acc: 0.9787
# starting round 95
# clients:  [77  4 70 38 33 91 60 11 73 27]
# round 95, starting client 1/10, id: 77
# round 95, starting client 2/10, id: 4
# round 95, starting client 3/10, id: 70
# round 95, starting client 4/10, id: 38
# round 95, starting client 5/10, id: 33
# round 95, starting client 6/10, id: 91
# round 95, starting client 7/10, id: 60
# round 95, starting client 8/10, id: 11
# round 95, starting client 9/10, id: 73
# round 95, starting client 10/10, id: 27
# round 95, validation acc: 0.9789
# starting round 96
# clients:  [ 5 98 87 57 17 49 44 13  1  0]
# round 96, starting client 1/10, id: 5
# round 96, starting client 2/10, id: 98
# round 96, starting client 3/10, id: 87
# round 96, starting client 4/10, id: 57
# round 96, starting client 5/10, id: 17
# round 96, starting client 6/10, id: 49
# round 96, starting client 7/10, id: 44
# round 96, starting client 8/10, id: 13
# round 96, starting client 9/10, id: 1
# round 96, starting client 10/10, id: 0
# round 96, validation acc: 0.9782
# starting round 97
# clients:  [27  3 46 74 96 35 68 13 16 41]
# round 97, starting client 1/10, id: 27
# round 97, starting client 2/10, id: 3
# round 97, starting client 3/10, id: 46
# round 97, starting client 4/10, id: 74
# round 97, starting client 5/10, id: 96
# round 97, starting client 6/10, id: 35
# round 97, starting client 7/10, id: 68
# round 97, starting client 8/10, id: 13
# round 97, starting client 9/10, id: 16
# round 97, starting client 10/10, id: 41
# round 97, validation acc: 0.9785
# starting round 98
# clients:  [79 10 44  4  7 45 26 32 49 39]
# round 98, starting client 1/10, id: 79
# round 98, starting client 2/10, id: 10
# round 98, starting client 3/10, id: 44
# round 98, starting client 4/10, id: 4
# round 98, starting client 5/10, id: 7
# round 98, starting client 6/10, id: 45
# round 98, starting client 7/10, id: 26
# round 98, starting client 8/10, id: 32
# round 98, starting client 9/10, id: 49
# round 98, starting client 10/10, id: 39
# round 98, validation acc: 0.9788
# starting round 99
# clients:  [99 20 50 12 76 82 61 77 22 91]
# round 99, starting client 1/10, id: 99
# round 99, starting client 2/10, id: 20
# round 99, starting client 3/10, id: 50
# round 99, starting client 4/10, id: 12
# round 99, starting client 5/10, id: 76
# round 99, starting client 6/10, id: 82
# round 99, starting client 7/10, id: 61
# round 99, starting client 8/10, id: 77
# round 99, starting client 9/10, id: 22
# round 99, starting client 10/10, id: 91
# round 99, validation acc: 0.9788
# [0.8103 0.8811 0.8982 0.9065 0.915  0.9198 0.9253 0.9292 0.9308 0.9345
#  0.939  0.9381 0.941  0.9438 0.9457 0.9478 0.9482 0.952  0.9515 0.9524
#  0.9529 0.9543 0.9542 0.9577 0.957  0.9599 0.9577 0.9602 0.9629 0.9613
#  0.9639 0.9624 0.964  0.9635 0.9634 0.964  0.9654 0.9654 0.9671 0.9674
#  0.9687 0.97   0.9704 0.9704 0.9698 0.9709 0.9708 0.9711 0.9708 0.9719
#  0.9713 0.9709 0.9722 0.9731 0.9733 0.9735 0.9736 0.9728 0.9734 0.9749
#  0.9747 0.9751 0.9759 0.9762 0.9748 0.9758 0.9769 0.9763 0.9756 0.9755
#  0.9766 0.9771 0.9758 0.9751 0.9773 0.9768 0.9776 0.9769 0.9763 0.9765
#  0.9773 0.9763 0.9771 0.9762 0.9765 0.9785 0.9785 0.9769 0.9778 0.9787
#  0.9794 0.9767 0.9785 0.9786 0.9787 0.9789 0.9782 0.9785 0.9788 0.9788]

# %%
# MLP - iid - m=50 experiment
mlp_iid_m50 = copy.deepcopy(mlp)
acc_mlp_iid_m50 = fed_avg_experiment(mlp_iid_m50, num_clients_per_round=50, 
                                 num_local_epochs=1,
                                 lr=0.05,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=100,
                                 filename='./acc_mlp_iid_m50')
print(acc_mlp_iid_m50)
np.save('./acc_mlp_iid_m50.npy', acc_mlp_iid_m50)
# Out:
# starting round 0
# clients:  [17 81 45 49 71 62  2 92  5 10 97 99 24 16 26 80 32 86 76 37 43 93 44 34
#   4 67 55 30 33 39 14 31 23  7 60 48 77 90 42 21 94 53 41 85 70 65 89 20
#  79 84]
# round 0, starting client 1/50, id: 17
# round 0, starting client 2/50, id: 81
# round 0, starting client 3/50, id: 45
# round 0, starting client 4/50, id: 49
# round 0, starting client 5/50, id: 71
# round 0, starting client 6/50, id: 62
# round 0, starting client 7/50, id: 2
# round 0, starting client 8/50, id: 92
# round 0, starting client 9/50, id: 5
# round 0, starting client 10/50, id: 10
# round 0, starting client 11/50, id: 97
# round 0, starting client 12/50, id: 99
# round 0, starting client 13/50, id: 24
# round 0, starting client 14/50, id: 16
# round 0, starting client 15/50, id: 26
# round 0, starting client 16/50, id: 80
# round 0, starting client 17/50, id: 32
# round 0, starting client 18/50, id: 86
# round 0, starting client 19/50, id: 76
# round 0, starting client 20/50, id: 37
# round 0, starting client 21/50, id: 43
# round 0, starting client 22/50, id: 93
# round 0, starting client 23/50, id: 44
# round 0, starting client 24/50, id: 34
# round 0, starting client 25/50, id: 4
# round 0, starting client 26/50, id: 67
# round 0, starting client 27/50, id: 55
# round 0, starting client 28/50, id: 30
# round 0, starting client 29/50, id: 33
# round 0, starting client 30/50, id: 39
# round 0, starting client 31/50, id: 14
# round 0, starting client 32/50, id: 31
# round 0, starting client 33/50, id: 23
# round 0, starting client 34/50, id: 7
# round 0, starting client 35/50, id: 60
# round 0, starting client 36/50, id: 48
# round 0, starting client 37/50, id: 77
# round 0, starting client 38/50, id: 90
# round 0, starting client 39/50, id: 42
# round 0, starting client 40/50, id: 21
# round 0, starting client 41/50, id: 94
# round 0, starting client 42/50, id: 53
# round 0, starting client 43/50, id: 41
# round 0, starting client 44/50, id: 85
# round 0, starting client 45/50, id: 70
# round 0, starting client 46/50, id: 65
# round 0, starting client 47/50, id: 89
# round 0, starting client 48/50, id: 20
# round 0, starting client 49/50, id: 79
# round 0, starting client 50/50, id: 84
# round 0, validation acc: 0.8163
# starting round 1
# clients:  [19 25 50 55  3 72 46 71 26  1 81 47 76 98 48 80 78 73  0 20 96 63 93 77
#  11 60 16 36 39 54 95 21 61 91 42 35 18 52 86 51 64 14 58 33 49 38 43  5
#  44  6]
# round 1, starting client 1/50, id: 19
# round 1, starting client 2/50, id: 25
# round 1, starting client 3/50, id: 50
# round 1, starting client 4/50, id: 55
# round 1, starting client 5/50, id: 3
# round 1, starting client 6/50, id: 72
# round 1, starting client 7/50, id: 46
# round 1, starting client 8/50, id: 71
# round 1, starting client 9/50, id: 26
# round 1, starting client 10/50, id: 1
# round 1, starting client 11/50, id: 81
# round 1, starting client 12/50, id: 47
# round 1, starting client 13/50, id: 76
# round 1, starting client 14/50, id: 98
# round 1, starting client 15/50, id: 48
# round 1, starting client 16/50, id: 80
# round 1, starting client 17/50, id: 78
# round 1, starting client 18/50, id: 73
# round 1, starting client 19/50, id: 0
# round 1, starting client 20/50, id: 20
# round 1, starting client 21/50, id: 96
# round 1, starting client 22/50, id: 63
# round 1, starting client 23/50, id: 93
# round 1, starting client 24/50, id: 77
# round 1, starting client 25/50, id: 11
# round 1, starting client 26/50, id: 60
# round 1, starting client 27/50, id: 16
# round 1, starting client 28/50, id: 36
# round 1, starting client 29/50, id: 39
# round 1, starting client 30/50, id: 54
# round 1, starting client 31/50, id: 95
# round 1, starting client 32/50, id: 21
# round 1, starting client 33/50, id: 61
# round 1, starting client 34/50, id: 91
# round 1, starting client 35/50, id: 42
# round 1, starting client 36/50, id: 35
# round 1, starting client 37/50, id: 18
# round 1, starting client 38/50, id: 52
# round 1, starting client 39/50, id: 86
# round 1, starting client 40/50, id: 51
# round 1, starting client 41/50, id: 64
# round 1, starting client 42/50, id: 14
# round 1, starting client 43/50, id: 58
# round 1, starting client 44/50, id: 33
# round 1, starting client 45/50, id: 49
# round 1, starting client 46/50, id: 38
# round 1, starting client 47/50, id: 43
# round 1, starting client 48/50, id: 5
# round 1, starting client 49/50, id: 44
# round 1, starting client 50/50, id: 6
# round 1, validation acc: 0.8808
# starting round 2
# clients:  [33 65 72 40 73 36 91 54 11 71  2 31 88 76 96 86 78 90 89 23 94  4 70 16
#  93 35 38 95 66  1 48 15 22 29 46 61 32 21 44 85 75 92 59 17 14  6  3 80
#  67 56]
# round 2, starting client 1/50, id: 33
# round 2, starting client 2/50, id: 65
# round 2, starting client 3/50, id: 72
# round 2, starting client 4/50, id: 40
# round 2, starting client 5/50, id: 73
# round 2, starting client 6/50, id: 36
# round 2, starting client 7/50, id: 91
# round 2, starting client 8/50, id: 54
# round 2, starting client 9/50, id: 11
# round 2, starting client 10/50, id: 71
# round 2, starting client 11/50, id: 2
# round 2, starting client 12/50, id: 31
# round 2, starting client 13/50, id: 88
# round 2, starting client 14/50, id: 76
# round 2, starting client 15/50, id: 96
# round 2, starting client 16/50, id: 86
# round 2, starting client 17/50, id: 78
# round 2, starting client 18/50, id: 90
# round 2, starting client 19/50, id: 89
# round 2, starting client 20/50, id: 23
# round 2, starting client 21/50, id: 94
# round 2, starting client 22/50, id: 4
# round 2, starting client 23/50, id: 70
# round 2, starting client 24/50, id: 16
# round 2, starting client 25/50, id: 93
# round 2, starting client 26/50, id: 35
# round 2, starting client 27/50, id: 38
# round 2, starting client 28/50, id: 95
# round 2, starting client 29/50, id: 66
# round 2, starting client 30/50, id: 1
# round 2, starting client 31/50, id: 48
# round 2, starting client 32/50, id: 15
# round 2, starting client 33/50, id: 22
# round 2, starting client 34/50, id: 29
# round 2, starting client 35/50, id: 46
# round 2, starting client 36/50, id: 61
# round 2, starting client 37/50, id: 32
# round 2, starting client 38/50, id: 21
# round 2, starting client 39/50, id: 44
# round 2, starting client 40/50, id: 85
# round 2, starting client 41/50, id: 75
# round 2, starting client 42/50, id: 92
# round 2, starting client 43/50, id: 59
# round 2, starting client 44/50, id: 17
# round 2, starting client 45/50, id: 14
# round 2, starting client 46/50, id: 6
# round 2, starting client 47/50, id: 3
# round 2, starting client 48/50, id: 80
# round 2, starting client 49/50, id: 67
# round 2, starting client 50/50, id: 56
# round 2, validation acc: 0.9
# starting round 3
# clients:  [29 22 83 16 44 12 43  2  8 54 36 48 32 79 86 53 85 47 76 91  4 26 52 42
#  13 57 69 72 80 10 71 59  3 25 65 64 27 19  0 51 17 82 73 31 14  5 34 23
#  78 18]
# round 3, starting client 1/50, id: 29
# round 3, starting client 2/50, id: 22
# round 3, starting client 3/50, id: 83
# round 3, starting client 4/50, id: 16
# round 3, starting client 5/50, id: 44
# round 3, starting client 6/50, id: 12
# round 3, starting client 7/50, id: 43
# round 3, starting client 8/50, id: 2
# round 3, starting client 9/50, id: 8
# round 3, starting client 10/50, id: 54
# round 3, starting client 11/50, id: 36
# round 3, starting client 12/50, id: 48
# round 3, starting client 13/50, id: 32
# round 3, starting client 14/50, id: 79
# round 3, starting client 15/50, id: 86
# round 3, starting client 16/50, id: 53
# round 3, starting client 17/50, id: 85
# round 3, starting client 18/50, id: 47
# round 3, starting client 19/50, id: 76
# round 3, starting client 20/50, id: 91
# round 3, starting client 21/50, id: 4
# round 3, starting client 22/50, id: 26
# round 3, starting client 23/50, id: 52
# round 3, starting client 24/50, id: 42
# round 3, starting client 25/50, id: 13
# round 3, starting client 26/50, id: 57
# round 3, starting client 27/50, id: 69
# round 3, starting client 28/50, id: 72
# round 3, starting client 29/50, id: 80
# round 3, starting client 30/50, id: 10
# round 3, starting client 31/50, id: 71
# round 3, starting client 32/50, id: 59
# round 3, starting client 33/50, id: 3
# round 3, starting client 34/50, id: 25
# round 3, starting client 35/50, id: 65
# round 3, starting client 36/50, id: 64
# round 3, starting client 37/50, id: 27
# round 3, starting client 38/50, id: 19
# round 3, starting client 39/50, id: 0
# round 3, starting client 40/50, id: 51
# round 3, starting client 41/50, id: 17
# round 3, starting client 42/50, id: 82
# round 3, starting client 43/50, id: 73
# round 3, starting client 44/50, id: 31
# round 3, starting client 45/50, id: 14
# round 3, starting client 46/50, id: 5
# round 3, starting client 47/50, id: 34
# round 3, starting client 48/50, id: 23
# round 3, starting client 49/50, id: 78
# round 3, starting client 50/50, id: 18
# round 3, validation acc: 0.9111
# starting round 4
# clients:  [24 93 94 29 79 25 58 96 87 11 66 63 84 69 78 35 13 75  8 34 41 91  0 85
#  43 36 57 74 39 99 40 49 16 51 64 98 62  1 38 56 80 30 70 67 17 46 89 95
#  82 20]
# round 4, starting client 1/50, id: 24
# round 4, starting client 2/50, id: 93
# round 4, starting client 3/50, id: 94
# round 4, starting client 4/50, id: 29
# round 4, starting client 5/50, id: 79
# round 4, starting client 6/50, id: 25
# round 4, starting client 7/50, id: 58
# round 4, starting client 8/50, id: 96
# round 4, starting client 9/50, id: 87
# round 4, starting client 10/50, id: 11
# round 4, starting client 11/50, id: 66
# round 4, starting client 12/50, id: 63
# round 4, starting client 13/50, id: 84
# round 4, starting client 14/50, id: 69
# round 4, starting client 15/50, id: 78
# round 4, starting client 16/50, id: 35
# round 4, starting client 17/50, id: 13
# round 4, starting client 18/50, id: 75
# round 4, starting client 19/50, id: 8
# round 4, starting client 20/50, id: 34
# round 4, starting client 21/50, id: 41
# round 4, starting client 22/50, id: 91
# round 4, starting client 23/50, id: 0
# round 4, starting client 24/50, id: 85
# round 4, starting client 25/50, id: 43
# round 4, starting client 26/50, id: 36
# round 4, starting client 27/50, id: 57
# round 4, starting client 28/50, id: 74
# round 4, starting client 29/50, id: 39
# round 4, starting client 30/50, id: 99
# round 4, starting client 31/50, id: 40
# round 4, starting client 32/50, id: 49
# round 4, starting client 33/50, id: 16
# round 4, starting client 34/50, id: 51
# round 4, starting client 35/50, id: 64
# round 4, starting client 36/50, id: 98
# round 4, starting client 37/50, id: 62
# round 4, starting client 38/50, id: 1
# round 4, starting client 39/50, id: 38
# round 4, starting client 40/50, id: 56
# round 4, starting client 41/50, id: 80
# round 4, starting client 42/50, id: 30
# round 4, starting client 43/50, id: 70
# round 4, starting client 44/50, id: 67
# round 4, starting client 45/50, id: 17
# round 4, starting client 46/50, id: 46
# round 4, starting client 47/50, id: 89
# round 4, starting client 48/50, id: 95
# round 4, starting client 49/50, id: 82
# round 4, starting client 50/50, id: 20
# round 4, validation acc: 0.9159
# starting round 5
# clients:  [59 25 91 84 75 38 27 46 87 15  9 45 17  0 20 73 11 89 57 44 12 32 97 13
#  23 52 50 21 41 14  6 16 80 39 30 36 54 72 35 31 96  2 55 74 92 85 26 99
#  94 10]
# round 5, starting client 1/50, id: 59
# round 5, starting client 2/50, id: 25
# round 5, starting client 3/50, id: 91
# round 5, starting client 4/50, id: 84
# round 5, starting client 5/50, id: 75
# round 5, starting client 6/50, id: 38
# round 5, starting client 7/50, id: 27
# round 5, starting client 8/50, id: 46
# round 5, starting client 9/50, id: 87
# round 5, starting client 10/50, id: 15
# round 5, starting client 11/50, id: 9
# round 5, starting client 12/50, id: 45
# round 5, starting client 13/50, id: 17
# round 5, starting client 14/50, id: 0
# round 5, starting client 15/50, id: 20
# round 5, starting client 16/50, id: 73
# round 5, starting client 17/50, id: 11
# round 5, starting client 18/50, id: 89
# round 5, starting client 19/50, id: 57
# round 5, starting client 20/50, id: 44
# round 5, starting client 21/50, id: 12
# round 5, starting client 22/50, id: 32
# round 5, starting client 23/50, id: 97
# round 5, starting client 24/50, id: 13
# round 5, starting client 25/50, id: 23
# round 5, starting client 26/50, id: 52
# round 5, starting client 27/50, id: 50
# round 5, starting client 28/50, id: 21
# round 5, starting client 29/50, id: 41
# round 5, starting client 30/50, id: 14
# round 5, starting client 31/50, id: 6
# round 5, starting client 32/50, id: 16
# round 5, starting client 33/50, id: 80
# round 5, starting client 34/50, id: 39
# round 5, starting client 35/50, id: 30
# round 5, starting client 36/50, id: 36
# round 5, starting client 37/50, id: 54
# round 5, starting client 38/50, id: 72
# round 5, starting client 39/50, id: 35
# round 5, starting client 40/50, id: 31
# round 5, starting client 41/50, id: 96
# round 5, starting client 42/50, id: 2
# round 5, starting client 43/50, id: 55
# round 5, starting client 44/50, id: 74
# round 5, starting client 45/50, id: 92
# round 5, starting client 46/50, id: 85
# round 5, starting client 47/50, id: 26
# round 5, starting client 48/50, id: 99
# round 5, starting client 49/50, id: 94
# round 5, starting client 50/50, id: 10
# round 5, validation acc: 0.9235
# starting round 6
# clients:  [ 1 36 89 52  2 58 15 67 96 59 32 20 95 27 99 61 82 81 22 40 12 16 77 53
#  84 64 19 97 57 55 92 54 29  7 11 47 46  4 63 94 31 37 24 60 43  0 73 83
#  75 85]
# round 6, starting client 1/50, id: 1
# round 6, starting client 2/50, id: 36
# round 6, starting client 3/50, id: 89
# round 6, starting client 4/50, id: 52
# round 6, starting client 5/50, id: 2
# round 6, starting client 6/50, id: 58
# round 6, starting client 7/50, id: 15
# round 6, starting client 8/50, id: 67
# round 6, starting client 9/50, id: 96
# round 6, starting client 10/50, id: 59
# round 6, starting client 11/50, id: 32
# round 6, starting client 12/50, id: 20
# round 6, starting client 13/50, id: 95
# round 6, starting client 14/50, id: 27
# round 6, starting client 15/50, id: 99
# round 6, starting client 16/50, id: 61
# round 6, starting client 17/50, id: 82
# round 6, starting client 18/50, id: 81
# round 6, starting client 19/50, id: 22
# round 6, starting client 20/50, id: 40
# round 6, starting client 21/50, id: 12
# round 6, starting client 22/50, id: 16
# round 6, starting client 23/50, id: 77
# round 6, starting client 24/50, id: 53
# round 6, starting client 25/50, id: 84
# round 6, starting client 26/50, id: 64
# round 6, starting client 27/50, id: 19
# round 6, starting client 28/50, id: 97
# round 6, starting client 29/50, id: 57
# round 6, starting client 30/50, id: 55
# round 6, starting client 31/50, id: 92
# round 6, starting client 32/50, id: 54
# round 6, starting client 33/50, id: 29
# round 6, starting client 34/50, id: 7
# round 6, starting client 35/50, id: 11
# round 6, starting client 36/50, id: 47
# round 6, starting client 37/50, id: 46
# round 6, starting client 38/50, id: 4
# round 6, starting client 39/50, id: 63
# round 6, starting client 40/50, id: 94
# round 6, starting client 41/50, id: 31
# round 6, starting client 42/50, id: 37
# round 6, starting client 43/50, id: 24
# round 6, starting client 44/50, id: 60
# round 6, starting client 45/50, id: 43
# round 6, starting client 46/50, id: 0
# round 6, starting client 47/50, id: 73
# round 6, starting client 48/50, id: 83
# round 6, starting client 49/50, id: 75
# round 6, starting client 50/50, id: 85
# round 6, validation acc: 0.927
# starting round 7
# clients:  [57 25 96 86 44 59 41 76 20 45 99 52 11 74  7 47 34 60 46 29 36 37 91 58
#   3 92 53  1 22 38 31 68 10 30 90 28 89 15 18 97 35 21 13 64 98 33 95 23
#   4 73]
# round 7, starting client 1/50, id: 57
# round 7, starting client 2/50, id: 25
# round 7, starting client 3/50, id: 96
# round 7, starting client 4/50, id: 86
# round 7, starting client 5/50, id: 44
# round 7, starting client 6/50, id: 59
# round 7, starting client 7/50, id: 41
# round 7, starting client 8/50, id: 76
# round 7, starting client 9/50, id: 20
# round 7, starting client 10/50, id: 45
# round 7, starting client 11/50, id: 99
# round 7, starting client 12/50, id: 52
# round 7, starting client 13/50, id: 11
# round 7, starting client 14/50, id: 74
# round 7, starting client 15/50, id: 7
# round 7, starting client 16/50, id: 47
# round 7, starting client 17/50, id: 34
# round 7, starting client 18/50, id: 60
# round 7, starting client 19/50, id: 46
# round 7, starting client 20/50, id: 29
# round 7, starting client 21/50, id: 36
# round 7, starting client 22/50, id: 37
# round 7, starting client 23/50, id: 91
# round 7, starting client 24/50, id: 58
# round 7, starting client 25/50, id: 3
# round 7, starting client 26/50, id: 92
# round 7, starting client 27/50, id: 53
# round 7, starting client 28/50, id: 1
# round 7, starting client 29/50, id: 22
# round 7, starting client 30/50, id: 38
# round 7, starting client 31/50, id: 31
# round 7, starting client 32/50, id: 68
# round 7, starting client 33/50, id: 10
# round 7, starting client 34/50, id: 30
# round 7, starting client 35/50, id: 90
# round 7, starting client 36/50, id: 28
# round 7, starting client 37/50, id: 89
# round 7, starting client 38/50, id: 15
# round 7, starting client 39/50, id: 18
# round 7, starting client 40/50, id: 97
# round 7, starting client 41/50, id: 35
# round 7, starting client 42/50, id: 21
# round 7, starting client 43/50, id: 13
# round 7, starting client 44/50, id: 64
# round 7, starting client 45/50, id: 98
# round 7, starting client 46/50, id: 33
# round 7, starting client 47/50, id: 95
# round 7, starting client 48/50, id: 23
# round 7, starting client 49/50, id: 4
# round 7, starting client 50/50, id: 73
# round 7, validation acc: 0.9305
# starting round 8
# clients:  [39 90 27 32 56 34 13 97 17 41 65 26 40 77 63 45 83  2 71 25 98  8 11 61
#  43 24 70 53  0 82 35 79 74 21 87 92 54 51 55 81 60 23 18 50 73 85 75 15
#  99  9]
# round 8, starting client 1/50, id: 39
# round 8, starting client 2/50, id: 90
# round 8, starting client 3/50, id: 27
# round 8, starting client 4/50, id: 32
# round 8, starting client 5/50, id: 56
# round 8, starting client 6/50, id: 34
# round 8, starting client 7/50, id: 13
# round 8, starting client 8/50, id: 97
# round 8, starting client 9/50, id: 17
# round 8, starting client 10/50, id: 41
# round 8, starting client 11/50, id: 65
# round 8, starting client 12/50, id: 26
# round 8, starting client 13/50, id: 40
# round 8, starting client 14/50, id: 77
# round 8, starting client 15/50, id: 63
# round 8, starting client 16/50, id: 45
# round 8, starting client 17/50, id: 83
# round 8, starting client 18/50, id: 2
# round 8, starting client 19/50, id: 71
# round 8, starting client 20/50, id: 25
# round 8, starting client 21/50, id: 98
# round 8, starting client 22/50, id: 8
# round 8, starting client 23/50, id: 11
# round 8, starting client 24/50, id: 61
# round 8, starting client 25/50, id: 43
# round 8, starting client 26/50, id: 24
# round 8, starting client 27/50, id: 70
# round 8, starting client 28/50, id: 53
# round 8, starting client 29/50, id: 0
# round 8, starting client 30/50, id: 82
# round 8, starting client 31/50, id: 35
# round 8, starting client 32/50, id: 79
# round 8, starting client 33/50, id: 74
# round 8, starting client 34/50, id: 21
# round 8, starting client 35/50, id: 87
# round 8, starting client 36/50, id: 92
# round 8, starting client 37/50, id: 54
# round 8, starting client 38/50, id: 51
# round 8, starting client 39/50, id: 55
# round 8, starting client 40/50, id: 81
# round 8, starting client 41/50, id: 60
# round 8, starting client 42/50, id: 23
# round 8, starting client 43/50, id: 18
# round 8, starting client 44/50, id: 50
# round 8, starting client 45/50, id: 73
# round 8, starting client 46/50, id: 85
# round 8, starting client 47/50, id: 75
# round 8, starting client 48/50, id: 15
# round 8, starting client 49/50, id: 99
# round 8, starting client 50/50, id: 9
# round 8, validation acc: 0.9335
# starting round 9
# clients:  [80 16 56 67 84 87 74  9 57 60 86 78 50 95 71 72 68 90 34  5 42 69 37  8
#  29 96 54  2 55 82  7  4 45 91 58 21 52 88 48  1 83 93 32 73 38 81 85 43
#  61 89]
# round 9, starting client 1/50, id: 80
# round 9, starting client 2/50, id: 16
# round 9, starting client 3/50, id: 56
# round 9, starting client 4/50, id: 67
# round 9, starting client 5/50, id: 84
# round 9, starting client 6/50, id: 87
# round 9, starting client 7/50, id: 74
# round 9, starting client 8/50, id: 9
# round 9, starting client 9/50, id: 57
# round 9, starting client 10/50, id: 60
# round 9, starting client 11/50, id: 86
# round 9, starting client 12/50, id: 78
# round 9, starting client 13/50, id: 50
# round 9, starting client 14/50, id: 95
# round 9, starting client 15/50, id: 71
# round 9, starting client 16/50, id: 72
# round 9, starting client 17/50, id: 68
# round 9, starting client 18/50, id: 90
# round 9, starting client 19/50, id: 34
# round 9, starting client 20/50, id: 5
# round 9, starting client 21/50, id: 42
# round 9, starting client 22/50, id: 69
# round 9, starting client 23/50, id: 37
# round 9, starting client 24/50, id: 8
# round 9, starting client 25/50, id: 29
# round 9, starting client 26/50, id: 96
# round 9, starting client 27/50, id: 54
# round 9, starting client 28/50, id: 2
# round 9, starting client 29/50, id: 55
# round 9, starting client 30/50, id: 82
# round 9, starting client 31/50, id: 7
# round 9, starting client 32/50, id: 4
# round 9, starting client 33/50, id: 45
# round 9, starting client 34/50, id: 91
# round 9, starting client 35/50, id: 58
# round 9, starting client 36/50, id: 21
# round 9, starting client 37/50, id: 52
# round 9, starting client 38/50, id: 88
# round 9, starting client 39/50, id: 48
# round 9, starting client 40/50, id: 1
# round 9, starting client 41/50, id: 83
# round 9, starting client 42/50, id: 93
# round 9, starting client 43/50, id: 32
# round 9, starting client 44/50, id: 73
# round 9, starting client 45/50, id: 38
# round 9, starting client 46/50, id: 81
# round 9, starting client 47/50, id: 85
# round 9, starting client 48/50, id: 43
# round 9, starting client 49/50, id: 61
# round 9, starting client 50/50, id: 89
# round 9, validation acc: 0.9365
# starting round 10
# clients:  [74  0 82 42 83 86 21 79 76 93 49 39 80 18  1 16 57  5  9 85 91 53 67 23
#  64 14 30 55 90 35 88 72 36 77 59 10  2 26 66 61 27 58 25 51 33 99 75 28
#  71 73]
# round 10, starting client 1/50, id: 74
# round 10, starting client 2/50, id: 0
# round 10, starting client 3/50, id: 82
# round 10, starting client 4/50, id: 42
# round 10, starting client 5/50, id: 83
# round 10, starting client 6/50, id: 86
# round 10, starting client 7/50, id: 21
# round 10, starting client 8/50, id: 79
# round 10, starting client 9/50, id: 76
# round 10, starting client 10/50, id: 93
# round 10, starting client 11/50, id: 49
# round 10, starting client 12/50, id: 39
# round 10, starting client 13/50, id: 80
# round 10, starting client 14/50, id: 18
# round 10, starting client 15/50, id: 1
# round 10, starting client 16/50, id: 16
# round 10, starting client 17/50, id: 57
# round 10, starting client 18/50, id: 5
# round 10, starting client 19/50, id: 9
# round 10, starting client 20/50, id: 85
# round 10, starting client 21/50, id: 91
# round 10, starting client 22/50, id: 53
# round 10, starting client 23/50, id: 67
# round 10, starting client 24/50, id: 23
# round 10, starting client 25/50, id: 64
# round 10, starting client 26/50, id: 14
# round 10, starting client 27/50, id: 30
# round 10, starting client 28/50, id: 55
# round 10, starting client 29/50, id: 90
# round 10, starting client 30/50, id: 35
# round 10, starting client 31/50, id: 88
# round 10, starting client 32/50, id: 72
# round 10, starting client 33/50, id: 36
# round 10, starting client 34/50, id: 77
# round 10, starting client 35/50, id: 59
# round 10, starting client 36/50, id: 10
# round 10, starting client 37/50, id: 2
# round 10, starting client 38/50, id: 26
# round 10, starting client 39/50, id: 66
# round 10, starting client 40/50, id: 61
# round 10, starting client 41/50, id: 27
# round 10, starting client 42/50, id: 58
# round 10, starting client 43/50, id: 25
# round 10, starting client 44/50, id: 51
# round 10, starting client 45/50, id: 33
# round 10, starting client 46/50, id: 99
# round 10, starting client 47/50, id: 75
# round 10, starting client 48/50, id: 28
# round 10, starting client 49/50, id: 71
# round 10, starting client 50/50, id: 73
# round 10, validation acc: 0.9396
# starting round 11
# clients:  [19 13 21 77 37  8 56 17 96 82 14 89 28 38 69 65 47 39 33  2  4 73 88 20
#  45 92 70 83 57 84 86 26 27  0 72 58 18 62 35 50 29 63 44 42  7 15 94 54
#  23 12]
# round 11, starting client 1/50, id: 19
# round 11, starting client 2/50, id: 13
# round 11, starting client 3/50, id: 21
# round 11, starting client 4/50, id: 77
# round 11, starting client 5/50, id: 37
# round 11, starting client 6/50, id: 8
# round 11, starting client 7/50, id: 56
# round 11, starting client 8/50, id: 17
# round 11, starting client 9/50, id: 96
# round 11, starting client 10/50, id: 82
# round 11, starting client 11/50, id: 14
# round 11, starting client 12/50, id: 89
# round 11, starting client 13/50, id: 28
# round 11, starting client 14/50, id: 38
# round 11, starting client 15/50, id: 69
# round 11, starting client 16/50, id: 65
# round 11, starting client 17/50, id: 47
# round 11, starting client 18/50, id: 39
# round 11, starting client 19/50, id: 33
# round 11, starting client 20/50, id: 2
# round 11, starting client 21/50, id: 4
# round 11, starting client 22/50, id: 73
# round 11, starting client 23/50, id: 88
# round 11, starting client 24/50, id: 20
# round 11, starting client 25/50, id: 45
# round 11, starting client 26/50, id: 92
# round 11, starting client 27/50, id: 70
# round 11, starting client 28/50, id: 83
# round 11, starting client 29/50, id: 57
# round 11, starting client 30/50, id: 84
# round 11, starting client 31/50, id: 86
# round 11, starting client 32/50, id: 26
# round 11, starting client 33/50, id: 27
# round 11, starting client 34/50, id: 0
# round 11, starting client 35/50, id: 72
# round 11, starting client 36/50, id: 58
# round 11, starting client 37/50, id: 18
# round 11, starting client 38/50, id: 62
# round 11, starting client 39/50, id: 35
# round 11, starting client 40/50, id: 50
# round 11, starting client 41/50, id: 29
# round 11, starting client 42/50, id: 63
# round 11, starting client 43/50, id: 44
# round 11, starting client 44/50, id: 42
# round 11, starting client 45/50, id: 7
# round 11, starting client 46/50, id: 15
# round 11, starting client 47/50, id: 94
# round 11, starting client 48/50, id: 54
# round 11, starting client 49/50, id: 23
# round 11, starting client 50/50, id: 12
# round 11, validation acc: 0.9418
# starting round 12
# clients:  [72 91 59 71  4 60 11 67 20 41 62 25 24 13 10 65 76 80 74 28 18 95 54 83
#  61  0 36 64  9 78  1 79 88 30 99 43 85  2 66 57  6 75 93 92 52 19 49 42
#  87 21]
# round 12, starting client 1/50, id: 72
# round 12, starting client 2/50, id: 91
# round 12, starting client 3/50, id: 59
# round 12, starting client 4/50, id: 71
# round 12, starting client 5/50, id: 4
# round 12, starting client 6/50, id: 60
# round 12, starting client 7/50, id: 11
# round 12, starting client 8/50, id: 67
# round 12, starting client 9/50, id: 20
# round 12, starting client 10/50, id: 41
# round 12, starting client 11/50, id: 62
# round 12, starting client 12/50, id: 25
# round 12, starting client 13/50, id: 24
# round 12, starting client 14/50, id: 13
# round 12, starting client 15/50, id: 10
# round 12, starting client 16/50, id: 65
# round 12, starting client 17/50, id: 76
# round 12, starting client 18/50, id: 80
# round 12, starting client 19/50, id: 74
# round 12, starting client 20/50, id: 28
# round 12, starting client 21/50, id: 18
# round 12, starting client 22/50, id: 95
# round 12, starting client 23/50, id: 54
# round 12, starting client 24/50, id: 83
# round 12, starting client 25/50, id: 61
# round 12, starting client 26/50, id: 0
# round 12, starting client 27/50, id: 36
# round 12, starting client 28/50, id: 64
# round 12, starting client 29/50, id: 9
# round 12, starting client 30/50, id: 78
# round 12, starting client 31/50, id: 1
# round 12, starting client 32/50, id: 79
# round 12, starting client 33/50, id: 88
# round 12, starting client 34/50, id: 30
# round 12, starting client 35/50, id: 99
# round 12, starting client 36/50, id: 43
# round 12, starting client 37/50, id: 85
# round 12, starting client 38/50, id: 2
# round 12, starting client 39/50, id: 66
# round 12, starting client 40/50, id: 57
# round 12, starting client 41/50, id: 6
# round 12, starting client 42/50, id: 75
# round 12, starting client 43/50, id: 93
# round 12, starting client 44/50, id: 92
# round 12, starting client 45/50, id: 52
# round 12, starting client 46/50, id: 19
# round 12, starting client 47/50, id: 49
# round 12, starting client 48/50, id: 42
# round 12, starting client 49/50, id: 87
# round 12, starting client 50/50, id: 21
# round 12, validation acc: 0.9444
# starting round 13
# clients:  [99 92 71 42 59 29 76 34 33 88 67 12 35 22 23  7 80 81 72 73 32 38 93 54
#  58 25 11 44 39 82 24 65 30  4 77 63 97 15  1 19 75 85 27 70 17 91 60 84
#  31 61]
# round 13, starting client 1/50, id: 99
# round 13, starting client 2/50, id: 92
# round 13, starting client 3/50, id: 71
# round 13, starting client 4/50, id: 42
# round 13, starting client 5/50, id: 59
# round 13, starting client 6/50, id: 29
# round 13, starting client 7/50, id: 76
# round 13, starting client 8/50, id: 34
# round 13, starting client 9/50, id: 33
# round 13, starting client 10/50, id: 88
# round 13, starting client 11/50, id: 67
# round 13, starting client 12/50, id: 12
# round 13, starting client 13/50, id: 35
# round 13, starting client 14/50, id: 22
# round 13, starting client 15/50, id: 23
# round 13, starting client 16/50, id: 7
# round 13, starting client 17/50, id: 80
# round 13, starting client 18/50, id: 81
# round 13, starting client 19/50, id: 72
# round 13, starting client 20/50, id: 73
# round 13, starting client 21/50, id: 32
# round 13, starting client 22/50, id: 38
# round 13, starting client 23/50, id: 93
# round 13, starting client 24/50, id: 54
# round 13, starting client 25/50, id: 58
# round 13, starting client 26/50, id: 25
# round 13, starting client 27/50, id: 11
# round 13, starting client 28/50, id: 44
# round 13, starting client 29/50, id: 39
# round 13, starting client 30/50, id: 82
# round 13, starting client 31/50, id: 24
# round 13, starting client 32/50, id: 65
# round 13, starting client 33/50, id: 30
# round 13, starting client 34/50, id: 4
# round 13, starting client 35/50, id: 77
# round 13, starting client 36/50, id: 63
# round 13, starting client 37/50, id: 97
# round 13, starting client 38/50, id: 15
# round 13, starting client 39/50, id: 1
# round 13, starting client 40/50, id: 19
# round 13, starting client 41/50, id: 75
# round 13, starting client 42/50, id: 85
# round 13, starting client 43/50, id: 27
# round 13, starting client 44/50, id: 70
# round 13, starting client 45/50, id: 17
# round 13, starting client 46/50, id: 91
# round 13, starting client 47/50, id: 60
# round 13, starting client 48/50, id: 84
# round 13, starting client 49/50, id: 31
# round 13, starting client 50/50, id: 61
# round 13, validation acc: 0.9462
# starting round 14
# clients:  [24 48 38 18 72 47 28 74 96 93 50 58 46 41 84 61 35 76 82 49 53 86 12 25
#  81 14 88 15 63 22 31 26  7 75 33 23 37 77 44 51  9  5 54 98 92  4 13 40
#   8 29]
# round 14, starting client 1/50, id: 24
# round 14, starting client 2/50, id: 48
# round 14, starting client 3/50, id: 38
# round 14, starting client 4/50, id: 18
# round 14, starting client 5/50, id: 72
# round 14, starting client 6/50, id: 47
# round 14, starting client 7/50, id: 28
# round 14, starting client 8/50, id: 74
# round 14, starting client 9/50, id: 96
# round 14, starting client 10/50, id: 93
# round 14, starting client 11/50, id: 50
# round 14, starting client 12/50, id: 58
# round 14, starting client 13/50, id: 46
# round 14, starting client 14/50, id: 41
# round 14, starting client 15/50, id: 84
# round 14, starting client 16/50, id: 61
# round 14, starting client 17/50, id: 35
# round 14, starting client 18/50, id: 76
# round 14, starting client 19/50, id: 82
# round 14, starting client 20/50, id: 49
# round 14, starting client 21/50, id: 53
# round 14, starting client 22/50, id: 86
# round 14, starting client 23/50, id: 12
# round 14, starting client 24/50, id: 25
# round 14, starting client 25/50, id: 81
# round 14, starting client 26/50, id: 14
# round 14, starting client 27/50, id: 88
# round 14, starting client 28/50, id: 15
# round 14, starting client 29/50, id: 63
# round 14, starting client 30/50, id: 22
# round 14, starting client 31/50, id: 31
# round 14, starting client 32/50, id: 26
# round 14, starting client 33/50, id: 7
# round 14, starting client 34/50, id: 75
# round 14, starting client 35/50, id: 33
# round 14, starting client 36/50, id: 23
# round 14, starting client 37/50, id: 37
# round 14, starting client 38/50, id: 77
# round 14, starting client 39/50, id: 44
# round 14, starting client 40/50, id: 51
# round 14, starting client 41/50, id: 9
# round 14, starting client 42/50, id: 5
# round 14, starting client 43/50, id: 54
# round 14, starting client 44/50, id: 98
# round 14, starting client 45/50, id: 92
# round 14, starting client 46/50, id: 4
# round 14, starting client 47/50, id: 13
# round 14, starting client 48/50, id: 40
# round 14, starting client 49/50, id: 8
# round 14, starting client 50/50, id: 29
# round 14, validation acc: 0.9476
# starting round 15
# clients:  [84 96 25  0 89 42  6 30 98 72  1 27 47 36 14 92 35 58 88 23 95 28 87 62
#  45 99  7  9 31 41 32 78 13 12 86 53 79 90 85 24 93  8 60 10 71 52 63 19
#  64 56]
# round 15, starting client 1/50, id: 84
# round 15, starting client 2/50, id: 96
# round 15, starting client 3/50, id: 25
# round 15, starting client 4/50, id: 0
# round 15, starting client 5/50, id: 89
# round 15, starting client 6/50, id: 42
# round 15, starting client 7/50, id: 6
# round 15, starting client 8/50, id: 30
# round 15, starting client 9/50, id: 98
# round 15, starting client 10/50, id: 72
# round 15, starting client 11/50, id: 1
# round 15, starting client 12/50, id: 27
# round 15, starting client 13/50, id: 47
# round 15, starting client 14/50, id: 36
# round 15, starting client 15/50, id: 14
# round 15, starting client 16/50, id: 92
# round 15, starting client 17/50, id: 35
# round 15, starting client 18/50, id: 58
# round 15, starting client 19/50, id: 88
# round 15, starting client 20/50, id: 23
# round 15, starting client 21/50, id: 95
# round 15, starting client 22/50, id: 28
# round 15, starting client 23/50, id: 87
# round 15, starting client 24/50, id: 62
# round 15, starting client 25/50, id: 45
# round 15, starting client 26/50, id: 99
# round 15, starting client 27/50, id: 7
# round 15, starting client 28/50, id: 9
# round 15, starting client 29/50, id: 31
# round 15, starting client 30/50, id: 41
# round 15, starting client 31/50, id: 32
# round 15, starting client 32/50, id: 78
# round 15, starting client 33/50, id: 13
# round 15, starting client 34/50, id: 12
# round 15, starting client 35/50, id: 86
# round 15, starting client 36/50, id: 53
# round 15, starting client 37/50, id: 79
# round 15, starting client 38/50, id: 90
# round 15, starting client 39/50, id: 85
# round 15, starting client 40/50, id: 24
# round 15, starting client 41/50, id: 93
# round 15, starting client 42/50, id: 8
# round 15, starting client 43/50, id: 60
# round 15, starting client 44/50, id: 10
# round 15, starting client 45/50, id: 71
# round 15, starting client 46/50, id: 52
# round 15, starting client 47/50, id: 63
# round 15, starting client 48/50, id: 19
# round 15, starting client 49/50, id: 64
# round 15, starting client 50/50, id: 56
# round 15, validation acc: 0.9496
# starting round 16
# clients:  [49 99 42 80 69 86 50 34 29 55 90 77 74 82 45 83 51  0 12 18 22 31 89 68
#  26 13 81 60 20 19 70 62 78 44 65 16 23 59  3 17 61 56 94 46 52 39  8 48
#  87 64]
# round 16, starting client 1/50, id: 49
# round 16, starting client 2/50, id: 99
# round 16, starting client 3/50, id: 42
# round 16, starting client 4/50, id: 80
# round 16, starting client 5/50, id: 69
# round 16, starting client 6/50, id: 86
# round 16, starting client 7/50, id: 50
# round 16, starting client 8/50, id: 34
# round 16, starting client 9/50, id: 29
# round 16, starting client 10/50, id: 55
# round 16, starting client 11/50, id: 90
# round 16, starting client 12/50, id: 77
# round 16, starting client 13/50, id: 74
# round 16, starting client 14/50, id: 82
# round 16, starting client 15/50, id: 45
# round 16, starting client 16/50, id: 83
# round 16, starting client 17/50, id: 51
# round 16, starting client 18/50, id: 0
# round 16, starting client 19/50, id: 12
# round 16, starting client 20/50, id: 18
# round 16, starting client 21/50, id: 22
# round 16, starting client 22/50, id: 31
# round 16, starting client 23/50, id: 89
# round 16, starting client 24/50, id: 68
# round 16, starting client 25/50, id: 26
# round 16, starting client 26/50, id: 13
# round 16, starting client 27/50, id: 81
# round 16, starting client 28/50, id: 60
# round 16, starting client 29/50, id: 20
# round 16, starting client 30/50, id: 19
# round 16, starting client 31/50, id: 70
# round 16, starting client 32/50, id: 62
# round 16, starting client 33/50, id: 78
# round 16, starting client 34/50, id: 44
# round 16, starting client 35/50, id: 65
# round 16, starting client 36/50, id: 16
# round 16, starting client 37/50, id: 23
# round 16, starting client 38/50, id: 59
# round 16, starting client 39/50, id: 3
# round 16, starting client 40/50, id: 17
# round 16, starting client 41/50, id: 61
# round 16, starting client 42/50, id: 56
# round 16, starting client 43/50, id: 94
# round 16, starting client 44/50, id: 46
# round 16, starting client 45/50, id: 52
# round 16, starting client 46/50, id: 39
# round 16, starting client 47/50, id: 8
# round 16, starting client 48/50, id: 48
# round 16, starting client 49/50, id: 87
# round 16, starting client 50/50, id: 64
# round 16, validation acc: 0.9506
# starting round 17
# clients:  [81 93 31 88 54 55 19 78 82 73 52  5 36 87 56 80 22 47 74 38 32 20 89 63
#  96  7 11 75 85 61 51 12 65 15 18 45 25  1 64 26 66 10 28 92 58 43 86 48
#  69 50]
# round 17, starting client 1/50, id: 81
# round 17, starting client 2/50, id: 93
# round 17, starting client 3/50, id: 31
# round 17, starting client 4/50, id: 88
# round 17, starting client 5/50, id: 54
# round 17, starting client 6/50, id: 55
# round 17, starting client 7/50, id: 19
# round 17, starting client 8/50, id: 78
# round 17, starting client 9/50, id: 82
# round 17, starting client 10/50, id: 73
# round 17, starting client 11/50, id: 52
# round 17, starting client 12/50, id: 5
# round 17, starting client 13/50, id: 36
# round 17, starting client 14/50, id: 87
# round 17, starting client 15/50, id: 56
# round 17, starting client 16/50, id: 80
# round 17, starting client 17/50, id: 22
# round 17, starting client 18/50, id: 47
# round 17, starting client 19/50, id: 74
# round 17, starting client 20/50, id: 38
# round 17, starting client 21/50, id: 32
# round 17, starting client 22/50, id: 20
# round 17, starting client 23/50, id: 89
# round 17, starting client 24/50, id: 63
# round 17, starting client 25/50, id: 96
# round 17, starting client 26/50, id: 7
# round 17, starting client 27/50, id: 11
# round 17, starting client 28/50, id: 75
# round 17, starting client 29/50, id: 85
# round 17, starting client 30/50, id: 61
# round 17, starting client 31/50, id: 51
# round 17, starting client 32/50, id: 12
# round 17, starting client 33/50, id: 65
# round 17, starting client 34/50, id: 15
# round 17, starting client 35/50, id: 18
# round 17, starting client 36/50, id: 45
# round 17, starting client 37/50, id: 25
# round 17, starting client 38/50, id: 1
# round 17, starting client 39/50, id: 64
# round 17, starting client 40/50, id: 26
# round 17, starting client 41/50, id: 66
# round 17, starting client 42/50, id: 10
# round 17, starting client 43/50, id: 28
# round 17, starting client 44/50, id: 92
# round 17, starting client 45/50, id: 58
# round 17, starting client 46/50, id: 43
# round 17, starting client 47/50, id: 86
# round 17, starting client 48/50, id: 48
# round 17, starting client 49/50, id: 69
# round 17, starting client 50/50, id: 50
# round 17, validation acc: 0.9509
# starting round 18
# clients:  [21 76  8  3 69 84 70 23 17 95 26  4 99 27 94 30 32 46 79  0 96 18 97 16
#  71 80 60 74 92 65 88 24 44 15 75 89 43 93 11 48 12  6 57 59 28 20 72 54
#  41 10]
# round 18, starting client 1/50, id: 21
# round 18, starting client 2/50, id: 76
# round 18, starting client 3/50, id: 8
# round 18, starting client 4/50, id: 3
# round 18, starting client 5/50, id: 69
# round 18, starting client 6/50, id: 84
# round 18, starting client 7/50, id: 70
# round 18, starting client 8/50, id: 23
# round 18, starting client 9/50, id: 17
# round 18, starting client 10/50, id: 95
# round 18, starting client 11/50, id: 26
# round 18, starting client 12/50, id: 4
# round 18, starting client 13/50, id: 99
# round 18, starting client 14/50, id: 27
# round 18, starting client 15/50, id: 94
# round 18, starting client 16/50, id: 30
# round 18, starting client 17/50, id: 32
# round 18, starting client 18/50, id: 46
# round 18, starting client 19/50, id: 79
# round 18, starting client 20/50, id: 0
# round 18, starting client 21/50, id: 96
# round 18, starting client 22/50, id: 18
# round 18, starting client 23/50, id: 97
# round 18, starting client 24/50, id: 16
# round 18, starting client 25/50, id: 71
# round 18, starting client 26/50, id: 80
# round 18, starting client 27/50, id: 60
# round 18, starting client 28/50, id: 74
# round 18, starting client 29/50, id: 92
# round 18, starting client 30/50, id: 65
# round 18, starting client 31/50, id: 88
# round 18, starting client 32/50, id: 24
# round 18, starting client 33/50, id: 44
# round 18, starting client 34/50, id: 15
# round 18, starting client 35/50, id: 75
# round 18, starting client 36/50, id: 89
# round 18, starting client 37/50, id: 43
# round 18, starting client 38/50, id: 93
# round 18, starting client 39/50, id: 11
# round 18, starting client 40/50, id: 48
# round 18, starting client 41/50, id: 12
# round 18, starting client 42/50, id: 6
# round 18, starting client 43/50, id: 57
# round 18, starting client 44/50, id: 59
# round 18, starting client 45/50, id: 28
# round 18, starting client 46/50, id: 20
# round 18, starting client 47/50, id: 72
# round 18, starting client 48/50, id: 54
# round 18, starting client 49/50, id: 41
# round 18, starting client 50/50, id: 10
# round 18, validation acc: 0.9527
# starting round 19
# clients:  [17 87  9  4 47 62 16 52 33 44 76 19 78 39  6 71 82 66 24 21 74 13 41 92
#   7 65 83 25 63 91 69 95 93 81 77 27 48 56 35 64 86 58 60 46 99 89 37 67
#  90 36]
# round 19, starting client 1/50, id: 17
# round 19, starting client 2/50, id: 87
# round 19, starting client 3/50, id: 9
# round 19, starting client 4/50, id: 4
# round 19, starting client 5/50, id: 47
# round 19, starting client 6/50, id: 62
# round 19, starting client 7/50, id: 16
# round 19, starting client 8/50, id: 52
# round 19, starting client 9/50, id: 33
# round 19, starting client 10/50, id: 44
# round 19, starting client 11/50, id: 76
# round 19, starting client 12/50, id: 19
# round 19, starting client 13/50, id: 78
# round 19, starting client 14/50, id: 39
# round 19, starting client 15/50, id: 6
# round 19, starting client 16/50, id: 71
# round 19, starting client 17/50, id: 82
# round 19, starting client 18/50, id: 66
# round 19, starting client 19/50, id: 24
# round 19, starting client 20/50, id: 21
# round 19, starting client 21/50, id: 74
# round 19, starting client 22/50, id: 13
# round 19, starting client 23/50, id: 41
# round 19, starting client 24/50, id: 92
# round 19, starting client 25/50, id: 7
# round 19, starting client 26/50, id: 65
# round 19, starting client 27/50, id: 83
# round 19, starting client 28/50, id: 25
# round 19, starting client 29/50, id: 63
# round 19, starting client 30/50, id: 91
# round 19, starting client 31/50, id: 69
# round 19, starting client 32/50, id: 95
# round 19, starting client 33/50, id: 93
# round 19, starting client 34/50, id: 81
# round 19, starting client 35/50, id: 77
# round 19, starting client 36/50, id: 27
# round 19, starting client 37/50, id: 48
# round 19, starting client 38/50, id: 56
# round 19, starting client 39/50, id: 35
# round 19, starting client 40/50, id: 64
# round 19, starting client 41/50, id: 86
# round 19, starting client 42/50, id: 58
# round 19, starting client 43/50, id: 60
# round 19, starting client 44/50, id: 46
# round 19, starting client 45/50, id: 99
# round 19, starting client 46/50, id: 89
# round 19, starting client 47/50, id: 37
# round 19, starting client 48/50, id: 67
# round 19, starting client 49/50, id: 90
# round 19, starting client 50/50, id: 36
# round 19, validation acc: 0.9544
# starting round 20
# clients:  [72 22 86 98 83 51 74 75 50 94 71 80 99 44  4 93 10 92 27  3 31 78 55  2
#  64 49 67  5 24 47 70 30 57 28 69 95 21 45 35 11 79 91 82 19 17 53 18  9
#  90 20]
# round 20, starting client 1/50, id: 72
# round 20, starting client 2/50, id: 22
# round 20, starting client 3/50, id: 86
# round 20, starting client 4/50, id: 98
# round 20, starting client 5/50, id: 83
# round 20, starting client 6/50, id: 51
# round 20, starting client 7/50, id: 74
# round 20, starting client 8/50, id: 75
# round 20, starting client 9/50, id: 50
# round 20, starting client 10/50, id: 94
# round 20, starting client 11/50, id: 71
# round 20, starting client 12/50, id: 80
# round 20, starting client 13/50, id: 99
# round 20, starting client 14/50, id: 44
# round 20, starting client 15/50, id: 4
# round 20, starting client 16/50, id: 93
# round 20, starting client 17/50, id: 10
# round 20, starting client 18/50, id: 92
# round 20, starting client 19/50, id: 27
# round 20, starting client 20/50, id: 3
# round 20, starting client 21/50, id: 31
# round 20, starting client 22/50, id: 78
# round 20, starting client 23/50, id: 55
# round 20, starting client 24/50, id: 2
# round 20, starting client 25/50, id: 64
# round 20, starting client 26/50, id: 49
# round 20, starting client 27/50, id: 67
# round 20, starting client 28/50, id: 5
# round 20, starting client 29/50, id: 24
# round 20, starting client 30/50, id: 47
# round 20, starting client 31/50, id: 70
# round 20, starting client 32/50, id: 30
# round 20, starting client 33/50, id: 57
# round 20, starting client 34/50, id: 28
# round 20, starting client 35/50, id: 69
# round 20, starting client 36/50, id: 95
# round 20, starting client 37/50, id: 21
# round 20, starting client 38/50, id: 45
# round 20, starting client 39/50, id: 35
# round 20, starting client 40/50, id: 11
# round 20, starting client 41/50, id: 79
# round 20, starting client 42/50, id: 91
# round 20, starting client 43/50, id: 82
# round 20, starting client 44/50, id: 19
# round 20, starting client 45/50, id: 17
# round 20, starting client 46/50, id: 53
# round 20, starting client 47/50, id: 18
# round 20, starting client 48/50, id: 9
# round 20, starting client 49/50, id: 90
# round 20, starting client 50/50, id: 20
# round 20, validation acc: 0.9556
# starting round 21
# clients:  [25 78 38 52 57 67 72  0  7 15 41 29 42 86 27 75 68  3 82 24 69 85 43 22
#  49 50 13 17 48 31 95  6 61 59 21 11 14 47 40 19 39 33 53 44 18 46 97 76
#  10  2]
# round 21, starting client 1/50, id: 25
# round 21, starting client 2/50, id: 78
# round 21, starting client 3/50, id: 38
# round 21, starting client 4/50, id: 52
# round 21, starting client 5/50, id: 57
# round 21, starting client 6/50, id: 67
# round 21, starting client 7/50, id: 72
# round 21, starting client 8/50, id: 0
# round 21, starting client 9/50, id: 7
# round 21, starting client 10/50, id: 15
# round 21, starting client 11/50, id: 41
# round 21, starting client 12/50, id: 29
# round 21, starting client 13/50, id: 42
# round 21, starting client 14/50, id: 86
# round 21, starting client 15/50, id: 27
# round 21, starting client 16/50, id: 75
# round 21, starting client 17/50, id: 68
# round 21, starting client 18/50, id: 3
# round 21, starting client 19/50, id: 82
# round 21, starting client 20/50, id: 24
# round 21, starting client 21/50, id: 69
# round 21, starting client 22/50, id: 85
# round 21, starting client 23/50, id: 43
# round 21, starting client 24/50, id: 22
# round 21, starting client 25/50, id: 49
# round 21, starting client 26/50, id: 50
# round 21, starting client 27/50, id: 13
# round 21, starting client 28/50, id: 17
# round 21, starting client 29/50, id: 48
# round 21, starting client 30/50, id: 31
# round 21, starting client 31/50, id: 95
# round 21, starting client 32/50, id: 6
# round 21, starting client 33/50, id: 61
# round 21, starting client 34/50, id: 59
# round 21, starting client 35/50, id: 21
# round 21, starting client 36/50, id: 11
# round 21, starting client 37/50, id: 14
# round 21, starting client 38/50, id: 47
# round 21, starting client 39/50, id: 40
# round 21, starting client 40/50, id: 19
# round 21, starting client 41/50, id: 39
# round 21, starting client 42/50, id: 33
# round 21, starting client 43/50, id: 53
# round 21, starting client 44/50, id: 44
# round 21, starting client 45/50, id: 18
# round 21, starting client 46/50, id: 46
# round 21, starting client 47/50, id: 97
# round 21, starting client 48/50, id: 76
# round 21, starting client 49/50, id: 10
# round 21, starting client 50/50, id: 2
# round 21, validation acc: 0.9559
# starting round 22
# clients:  [32  4 26 83 63 76  1 46 50 57 62 19 47  9  7 69  6 93 67 30 51 22 59 55
#  25 40  0 41 39 98 71 13 89 74 90 56 10 91 82 28 68 20 95 73 85 88 53 81
#   2 37]
# round 22, starting client 1/50, id: 32
# round 22, starting client 2/50, id: 4
# round 22, starting client 3/50, id: 26
# round 22, starting client 4/50, id: 83
# round 22, starting client 5/50, id: 63
# round 22, starting client 6/50, id: 76
# round 22, starting client 7/50, id: 1
# round 22, starting client 8/50, id: 46
# round 22, starting client 9/50, id: 50
# round 22, starting client 10/50, id: 57
# round 22, starting client 11/50, id: 62
# round 22, starting client 12/50, id: 19
# round 22, starting client 13/50, id: 47
# round 22, starting client 14/50, id: 9
# round 22, starting client 15/50, id: 7
# round 22, starting client 16/50, id: 69
# round 22, starting client 17/50, id: 6
# round 22, starting client 18/50, id: 93
# round 22, starting client 19/50, id: 67
# round 22, starting client 20/50, id: 30
# round 22, starting client 21/50, id: 51
# round 22, starting client 22/50, id: 22
# round 22, starting client 23/50, id: 59
# round 22, starting client 24/50, id: 55
# round 22, starting client 25/50, id: 25
# round 22, starting client 26/50, id: 40
# round 22, starting client 27/50, id: 0
# round 22, starting client 28/50, id: 41
# round 22, starting client 29/50, id: 39
# round 22, starting client 30/50, id: 98
# round 22, starting client 31/50, id: 71
# round 22, starting client 32/50, id: 13
# round 22, starting client 33/50, id: 89
# round 22, starting client 34/50, id: 74
# round 22, starting client 35/50, id: 90
# round 22, starting client 36/50, id: 56
# round 22, starting client 37/50, id: 10
# round 22, starting client 38/50, id: 91
# round 22, starting client 39/50, id: 82
# round 22, starting client 40/50, id: 28
# round 22, starting client 41/50, id: 68
# round 22, starting client 42/50, id: 20
# round 22, starting client 43/50, id: 95
# round 22, starting client 44/50, id: 73
# round 22, starting client 45/50, id: 85

# %%
# MLP - non-iid - m=10 experiment
mlp_noniid_m10 = copy.deepcopy(mlp)
acc_mlp_noniid_m10 = fed_avg_experiment(mlp_noniid_m10, num_clients_per_round=10, 
                                 num_local_epochs=1,
                                 lr=0.05,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=300,
                                 filename = './acc_mlp_noniid_m10')
print(acc_mlp_noniid_m10)
np.save('./acc_mlp_noniid_m10.npy', acc_mlp_noniid_m10)

# %%
# MLP - noniid - m=50 experiment
mlp_noniid_m50 = copy.deepcopy(mlp)
acc_mlp_noniid_m50 = fed_avg_experiment(mlp_noniid_m50, num_clients_per_round=50, 
                                 num_local_epochs=1,
                                 lr=0.05,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=300,
                                 filename='./acc_mlp_noniid_m50')
print(acc_mlp_noniid_m50)
np.save('./acc_mlp_noniid_m50.npy', acc_mlp_noniid_m50)

# %% [markdown]
# CNN EXPERIMENTS

# %%
cnn = CNN()
print(cnn)
print("total params: ", num_params(cnn))

# %%
# CNN - iid - m=10 experiment
cnn_iid_m10 = copy.deepcopy(cnn)
acc_cnn_iid_m10 = fed_avg_experiment(cnn_iid_m10, num_clients_per_round=10, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=100,
                                 filename='./acc_cnn_iid_m10')
print(acc_cnn_iid_m10)
np.save('./acc_cnn_iid_m10.npy', acc_cnn_iid_m10)

# %%
# CNN - iid - m=50 experiment
cnn_iid_m50 = copy.deepcopy(cnn)
acc_cnn_iid_m50 = fed_avg_experiment(cnn_iid_m50, num_clients_per_round=50, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = iid_client_train_loader,
                                 max_rounds=100,
                                 filename='./acc_cnn_iid_m50')
print(acc_cnn_iid_m50)
np.save('./acc_cnn_iid_m50.npy', acc_cnn_iid_m50)

# %%
# CNN - non-iid - m=10 experiment
cnn_noniid_m10 = copy.deepcopy(cnn)
acc_cnn_noniid_m10 = fed_avg_experiment(cnn_noniid_m10, num_clients_per_round=10, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=200,
                                 filename='./acc_cnn_noniid_m10')
print(acc_cnn_noniid_m10)
np.save('./acc_cnn_noniid_m10.npy', acc_cnn_noniid_m10)

# %%
# CNN - non-iid - m=50 experiment
cnn_noniid_m50 = copy.deepcopy(cnn)
acc_cnn_noniid_m50 = fed_avg_experiment(cnn_noniid_m50, num_clients_per_round=50, 
                                 num_local_epochs=5,
                                 lr=0.01,
                                 client_train_loader = noniid_client_train_loader,
                                 max_rounds=100,
                                 filename='./acc_cnn_noniid_m50')
print(acc_cnn_noniid_m50)
np.save('./acc_cnn_noniid_m50.npy', acc_cnn_noniid_m50)

# %%
# view_10(x_debug[:10].to(cpu), torch.argmax(model(x_debug),dim=1)[:10].to(cpu))

# m = CNN().to(cuda)
# m.train()
# lr = 0.01
# opt = torch.optim.SGD(m.parameters(), lr)

# for epoch in range(5):
#     for (t, (x,y)) in enumerate(train_loader):
#         x = x.to(cuda)
#         y = y.to(cuda)
#         opt.zero_grad()
#         out = m(x)
#         loss = criterion(out, y)
#         loss.backward()
#         opt.step()

#         if (t%100 == 0):
#             print("epoch {}, step {}, loss: {}".format(epoch, t, loss))

#     print("running validation")
#     acc = validate(m)
#     print("epoch {} validation acc: {}".format(epoch, acc))
