# %%
# Extract training and testing accuracies
accuracy_train = data['accuracy_train'] if 'accuracy_train' in data.files else None
accuracy_test = data['accuracy_test'] if 'accuracy_test' in data.files else None

# Check if the necessary data is available
if accuracy_train is not None and accuracy_test is not None:
    epochs = np.arange(len(accuracy_train))  # Assuming the accuracy arrays have one value per epoch

    # Plotting Accuracy
    plt.figure(figsize=(10, 5))
    plt.plot(epochs, accuracy_train, label='Training Accuracy', color='green')
    plt.plot(epochs, accuracy_test, label='Test Accuracy', color='red')
    plt.title('Training and Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()
    plt.show()
else:
    print("Training and/or Test Accuracy data not found in the .npz file.")

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load the .npz file
data = np.load('xp_58485.npz')

# Display the contents
print("Contents of the .npz file:")
print(data.files)

# Extract relevant metrics
loss_train = data['loss_train'] if 'loss_train' in data.files else None
loss_test = data['loss_test'] if 'loss_test' in data.files else None
accuracy_train = data['accuracy_train'] if 'accuracy_train' in data.files else None
accuracy_test = data['accuracy_test'] if 'accuracy_test' in data.files else None

# Create plots if data is available
if loss_train is not None and loss_test is not None:
    epochs = np.arange(len(loss_train))  # Assuming the loss arrays have one value per epoch

    # Plotting Losses
    plt.figure(figsize=(12, 5))
    plt.subplot(1, 2, 1)
    plt.plot(epochs, loss_train, label='Training Loss', color='blue')
    plt.plot(epochs, loss_test, label='Test Loss', color='orange')
    plt.title('Training and Test Loss over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid()

if accuracy_train is not None and accuracy_test is not None:
    # Plotting Accuracies
    plt.subplot(1, 2, 2)
    plt.plot(epochs, accuracy_train, label='Training Accuracy', color='green')
    plt.plot(epochs, accuracy_test, label='Test Accuracy', color='red')
    plt.title('Training and Test Accuracy over Epochs')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid()

plt.tight_layout()
plt.show()

# %%
import numpy as np

# Load results function
def load_results(path, filename):
    results_dict = np.load(f"{filename}.npz", allow_pickle=True)
    return results_dict

# Path to the .npz file
path = 'path/to/your/results'  # Update with your actual path
filename = 'xp_58485'  # Update with your actual filename without the .npz extension

# Load the results
results = load_results(path, filename)

# Print the available keys in the loaded results
print("Available keys in the results dictionary:")
for key in results:
    print(key)
    # If the key is 'parameters', print its sub-keys too
    if key == 'parameters':
        params = results[key][()]
        for param_key in params:
            print(f" - {param_key}")
# Out:
# Available keys in the results dictionary:
# hyperparameters
# hyperparameters_
# parameters
# communication_round
# lr
# epoch
# iteration
# client0_loss
# client1_loss
# client2_loss
# client3_loss
# client4_loss
# client5_loss
# client6_loss
# client7_loss
# client8_loss
# client9_loss
# client10_loss
# client11_loss
# client12_loss
# client13_loss
# client14_loss
# client15_loss
# client16_loss
# client17_loss
# client18_loss
# client19_loss
# client20_loss
# client21_loss
# client22_loss
# client23_loss
# client24_loss
# client25_loss
# client26_loss
# client27_loss
# client28_loss
# client29_loss
# client30_loss
# client31_loss
# client32_loss
# client33_loss
# client34_loss
# client35_loss
# client36_loss
# client37_loss
# client38_loss
# client39_loss
# client40_loss
# client41_loss
# client42_loss
# client43_loss
# client44_loss
# client45_loss
# client46_loss
# client47_loss
# client48_loss
# client49_loss
# client50_loss
# client51_loss
# client52_loss
# client53_loss
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load results function
def load_results(path, filename):
    results_dict = np.load(f"{filename}.npz", allow_pickle=True)
    return results_dict

# Path to the .npz file
 # Update with your actual path
filename = 'xp_58485'  # Update with your actual filename without the .npz extension
#xp_97317.npz
# Load the results
results = load_results(path, filename)

# Extract data from the loaded results
communication_rounds = results['communication_round']
loss_train = results['loss_train']           # Training loss
loss_test = results['loss_test']             # Test loss
accuracy_train = results['accuracy_train']   # Training accuracy
accuracy_test = results['accuracy_test']     # Test accuracy

# Create plots
plt.figure(figsize=(12, 6))

# Plot training and test loss
plt.subplot(1, 2, 1)
plt.plot(communication_rounds, loss_train, label='Train Loss', color='blue')
plt.plot(communication_rounds, loss_test, label='Test Loss', color='red')
plt.title(f'Loss over Communication Rounds\nDataset: mnist, Iterations: 2000, Clients: 2000')
plt.xlabel('Communication Rounds')
plt.ylabel('Loss')
plt.legend()

# Plot training and test accuracy
plt.subplot(1, 2, 2)
plt.plot(communication_rounds, accuracy_train, label='Train Accuracy', color='green')
plt.plot(communication_rounds, accuracy_test, label='Test Accuracy', color='orange')
plt.title(f'Accuracy over Communication Rounds\nDataset: mnist, Iterations: 2000, Clients: 2000')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()

# %%
#using ["stc_up", {"p_up" : ?}], compression technique

import numpy as np
import matplotlib.pyplot as plt

# Load results function
def load_results(path, filename):
    results_dict = np.load(f"{filename}.npz", allow_pickle=True)
    return results_dict

# Path to the .npz file
 # Update with your actual path
filename = 'xp_97317'  # Update with your actual filename without the .npz extension
#xp_97317.npz
# Load the results
results = load_results(path, filename)

# Extract data from the loaded results
communication_rounds = results['communication_round']
loss_train = results['loss_train']           # Training loss
loss_test = results['loss_test']             # Test loss
accuracy_train = results['accuracy_train']   # Training accuracy
accuracy_test = results['accuracy_test']     # Test accuracy

# Create plots
plt.figure(figsize=(12, 6))

# Plot training and test loss
plt.subplot(1, 2, 1)
plt.plot(communication_rounds, loss_train, label='Train Loss', color='blue')
plt.plot(communication_rounds, loss_test, label='Test Loss', color='red')
plt.title(f'Loss over Communication Rounds\nDataset: mnist, Iterations: 200, Clients: 50')
plt.xlabel('Communication Rounds')
plt.ylabel('Loss')
plt.legend()

# Plot training and test accuracy
plt.subplot(1, 2, 2)
plt.plot(communication_rounds, accuracy_train, label='Train Accuracy', color='green')
plt.plot(communication_rounds, accuracy_test, label='Test Accuracy', color='orange')
plt.title(f'Accuracy over Communication Rounds\nDataset: mnist, Iterations: 2000, Clients: 2000,Compression:STC UP')
plt.xlabel('Communication Rounds')
plt.ylabel('Accuracy')
plt.legend()

# Show the plots
plt.tight_layout()
plt.show()
